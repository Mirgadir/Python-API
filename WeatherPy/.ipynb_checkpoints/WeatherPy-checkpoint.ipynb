# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

number = -1
skip = 0
city_name=[]
temp =[]
cloud=[]
country=[]
date=[]
hum=[]
latitude=[]
long=[]
wind=[]
num =[]
print("Beginning of data collection")
print("--------------------------------")
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        temp.append(response['main']['temp_max'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        hum.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        number+=1
        num.append(number)
        print("Processing record  " +str(number+1)+ " and " + str(skip) + " skipped" + "|" + response['name'])
    except KeyError:
        skip+=1
        print(f"City was not found. Skiping... ")
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
weather_dic = {
    "City ID": num,"City": city_name, "Cloudiness":cloud, "Country":country, "Date": date, 
    "Humidity": hum, "Lat":latitude, "Lng":long, "Max Temp": temp,"Wind Speed": wind  
}
# Out:
# Beginning of data collection
# --------------------------------
# City was not found. Skiping...
# Processing record  1 and 1 skipped|Castro
# Processing record  2 and 1 skipped|Kapaa
# Processing record  3 and 1 skipped|Rikitea
# Processing record  4 and 1 skipped|Mataura
# Processing record  5 and 1 skipped|Tasiilaq
# Processing record  6 and 1 skipped|Thompson
# Processing record  7 and 1 skipped|Hobart
# Processing record  8 and 1 skipped|Khatanga
# Processing record  9 and 1 skipped|Albany
# Processing record  10 and 1 skipped|Djenné
# Processing record  11 and 1 skipped|Pisco
# Processing record  12 and 1 skipped|Katsuura
# Processing record  13 and 1 skipped|Bonavista
# Processing record  14 and 1 skipped|Leme
# Processing record  15 and 1 skipped|Nikolskoye
# Processing record  16 and 1 skipped|Bairiki Village
# Processing record  17 and 1 skipped|Mount Gambier
# Processing record  18 and 1 skipped|Upernavik
# Processing record  19 and 1 skipped|Dikson
# Processing record  20 and 1 skipped|Hilo
# Processing record  21 and 1 skipped|Cape Town
# Processing record  22 and 1 skipped|Busselton
# Processing record  23 and 1 skipped|Hong Kong
# City was not found. Skiping...
# Processing record  24 and 2 skipped|Bredasdorp
# Processing record  25 and 2 skipped|Barrow
# City was not found. Skiping...
# Processing record  26 and 3 skipped|Lokosovo
# Processing record  27 and 3 skipped|Mizdah
# Processing record  28 and 3 skipped|Ushuaia
# City was not found. Skiping...
# Processing record  29 and 4 skipped|Rāvar
# Processing record  30 and 4 skipped|Bac Lieu
# Processing record  31 and 4 skipped|Ponta do Sol
# Processing record  32 and 4 skipped|Xushan
# Processing record  33 and 4 skipped|Havre-St-Pierre
# Processing record  34 and 4 skipped|Cockburn Town
# Processing record  35 and 4 skipped|Vaini
# Processing record  36 and 4 skipped|Jamestown
# Processing record  37 and 4 skipped|Merauke
# Processing record  38 and 4 skipped|Tuatapere
# Processing record  39 and 4 skipped|Gold Coast
# Processing record  40 and 4 skipped|Hermanus
# Processing record  41 and 4 skipped|Chui
# Processing record  42 and 4 skipped|Kalevala
# Processing record  43 and 4 skipped|Yar-Sale
# Processing record  44 and 4 skipped|Yellowknife
# Processing record  45 and 4 skipped|Tuktoyaktuk
# Processing record  46 and 4 skipped|Alenquer
# Processing record  47 and 4 skipped|Bosaso
# Processing record  48 and 4 skipped|Chake Chake
# Processing record  49 and 4 skipped|New Norfolk
# Processing record  50 and 4 skipped|Port Alfred
# Processing record  51 and 4 skipped|São Filipe
# Processing record  52 and 4 skipped|Cap Malheureux
# Processing record  53 and 4 skipped|Catuday
# Processing record  54 and 4 skipped|Sørkjosen
# Processing record  55 and 4 skipped|Hofn
# Processing record  56 and 4 skipped|Jovellar
# Processing record  57 and 4 skipped|Karonga
# Processing record  58 and 4 skipped|Constantine
# Processing record  59 and 4 skipped|Kumul
# Processing record  60 and 4 skipped|Berbera
# Processing record  61 and 4 skipped|Bengkulu
# Processing record  62 and 4 skipped|Lagoa
# Processing record  63 and 4 skipped|Haibara-akanedai
# Processing record  64 and 4 skipped|Saint-Philippe
# Processing record  65 and 4 skipped|Marsaxlokk
# Processing record  66 and 4 skipped|Usta Muhammad
# Processing record  67 and 4 skipped|Punta Arenas
# Processing record  68 and 4 skipped|Quatre Cocos
# City was not found. Skiping...
# Processing record  69 and 5 skipped|Ulaangom
# Processing record  70 and 5 skipped|Antofagasta
# Processing record  71 and 5 skipped|George Town
# Processing record  72 and 5 skipped|Geraldton
# Processing record  73 and 5 skipped|Hithadhoo
# Processing record  74 and 5 skipped|Namanga
# Processing record  75 and 5 skipped|Vanimo
# Processing record  76 and 5 skipped|Port Moresby
# Processing record  77 and 5 skipped|Matara
# Processing record  78 and 5 skipped|Alice Springs
# Processing record  79 and 5 skipped|Sabzawār
# Processing record  80 and 5 skipped|Puerto Escondido
# Processing record  81 and 5 skipped|Butaritari
# Processing record  82 and 5 skipped|Neiafu
# Processing record  83 and 5 skipped|Avarua
# Processing record  84 and 5 skipped|Eyemouth
# Processing record  85 and 5 skipped|Jakar
# Processing record  86 and 5 skipped|Chokurdakh
# Processing record  87 and 5 skipped|Carnarvon
# Processing record  88 and 5 skipped|Biak
# Processing record  89 and 5 skipped|Rong Kwang
# Processing record  90 and 5 skipped|Atuona
# Processing record  91 and 5 skipped|Kiama
# Processing record  92 and 5 skipped|Fort Frances
# Processing record  93 and 5 skipped|Winnemucca
# Processing record  94 and 5 skipped|Bhātāpāra
# City was not found. Skiping...
# Processing record  95 and 6 skipped|Henties Bay
# Processing record  96 and 6 skipped|Mehamn
# Processing record  97 and 6 skipped|Concepción
# Processing record  98 and 6 skipped|Bariloche
# Processing record  99 and 6 skipped|Umluj
# Processing record  100 and 6 skipped|Chauk
# Processing record  101 and 6 skipped|Clyde River
# Processing record  102 and 6 skipped|Faya
# City was not found. Skiping...
# Processing record  103 and 7 skipped|Thanh Hoa
# Processing record  104 and 7 skipped|Danilovka
# Processing record  105 and 7 skipped|Codrington
# Processing record  106 and 7 skipped|Santa Inês
# Processing record  107 and 7 skipped|Herat Province
# Processing record  108 and 7 skipped|Nome
# Processing record  109 and 7 skipped|Esperance
# Processing record  110 and 7 skipped|Udachny
# Processing record  111 and 7 skipped|Lompoc
# Processing record  112 and 7 skipped|Port Hardy
# Processing record  113 and 7 skipped|Khovd
# Processing record  114 and 7 skipped|Margate
# Processing record  115 and 7 skipped|Marawi
# City was not found. Skiping...
# Processing record  116 and 8 skipped|Puerto Ayora
# Processing record  117 and 8 skipped|Novy Urengoy
# Processing record  118 and 8 skipped|Praia da Vitória
# Processing record  119 and 8 skipped|Marrakesh
# Processing record  120 and 8 skipped|Kyshtovka
# City was not found. Skiping...
# Processing record  121 and 9 skipped|Richards Bay
# Processing record  122 and 9 skipped|Souillac
# Processing record  123 and 9 skipped|Srednekolymsk
# Processing record  124 and 9 skipped|Taoudenni
# Processing record  125 and 9 skipped|Aswān
# Processing record  126 and 9 skipped|Berlevåg
# City was not found. Skiping...
# Processing record  127 and 10 skipped|Petropavlovsk-Kamchatskiy
# Processing record  128 and 10 skipped|Derzhavīnsk
# Processing record  129 and 10 skipped|Mulegé
# Processing record  130 and 10 skipped|Tikhvin
# City was not found. Skiping...
# Processing record  131 and 11 skipped|Chopinzinho
# Processing record  132 and 11 skipped|Rantepao
# City was not found. Skiping...
# Processing record  133 and 12 skipped|Asău
# Processing record  134 and 12 skipped|Guozhen
# Processing record  135 and 12 skipped|Turukhansk
# Processing record  136 and 12 skipped|Zalesovo
# Processing record  137 and 12 skipped|Port Lincoln
# Processing record  138 and 12 skipped|Los Llanos de Aridane
# Processing record  139 and 12 skipped|Evensk
# Processing record  140 and 12 skipped|Örnsköldsvik
# Processing record  141 and 12 skipped|Norman Wells
# Processing record  142 and 12 skipped|Leh
# Processing record  143 and 12 skipped|Bereda
# Processing record  144 and 12 skipped|Saint Stephen
# City was not found. Skiping...
# Processing record  145 and 13 skipped|Āsosa
# Processing record  146 and 13 skipped|Lima
# Processing record  147 and 13 skipped|Toamasina
# Processing record  148 and 13 skipped|Ribeira Grande
# Processing record  149 and 13 skipped|Soyo
# Processing record  150 and 13 skipped|Narsaq
# Processing record  151 and 13 skipped|San Policarpo
# Processing record  152 and 13 skipped|Nelson Bay
# Processing record  153 and 13 skipped|Sørland
# Processing record  154 and 13 skipped|Flin Flon
# Processing record  155 and 13 skipped|Fortuna
# Processing record  156 and 13 skipped|Pemangkat
# Processing record  157 and 13 skipped|Bluff
# City was not found. Skiping...
# Processing record  158 and 14 skipped|Puerto del Rosario
# Processing record  159 and 14 skipped|Anjiang
# Processing record  160 and 14 skipped|Kulhudhuffushi
# Processing record  161 and 14 skipped|Faanui
# Processing record  162 and 14 skipped|Vuktyl
# Processing record  163 and 14 skipped|Batemans Bay
# Processing record  164 and 14 skipped|Odesskoye
# Processing record  165 and 14 skipped|Kutum
# Processing record  166 and 14 skipped|College
# Processing record  167 and 14 skipped|Qeshm
# Processing record  168 and 14 skipped|Yulara
# Processing record  169 and 14 skipped|Sitka
# Processing record  170 and 14 skipped|Laas
# Processing record  171 and 14 skipped|Ossora
# Processing record  172 and 14 skipped|Yakeshi
# Processing record  173 and 14 skipped|Sakakah
# Processing record  174 and 14 skipped|Tevaitoa
# Processing record  175 and 14 skipped|Makīnsk
# Processing record  176 and 14 skipped|Abū Zabad
# Processing record  177 and 14 skipped|Samarai
# Processing record  178 and 14 skipped|Vila Franca do Campo
# Processing record  179 and 14 skipped|Pizarro
# Processing record  180 and 14 skipped|Fairbanks
# Processing record  181 and 14 skipped|Lusambo
# Processing record  182 and 14 skipped|Mayo
# Processing record  183 and 14 skipped|Severo-Kuril'sk
# Processing record  184 and 14 skipped|Port Elizabeth
# Processing record  185 and 14 skipped|Gambēla
# Processing record  186 and 14 skipped|Lebu
# City was not found. Skiping...
# Processing record  187 and 15 skipped|Salalah
# Processing record  188 and 15 skipped|Teberda
# Processing record  189 and 15 skipped|Saint Paul Harbor
# Processing record  190 and 15 skipped|Grindavik
# Processing record  191 and 15 skipped|Gamba
# Processing record  192 and 15 skipped|Marovoay
# Processing record  193 and 15 skipped|Lata
# City was not found. Skiping...
# Processing record  194 and 16 skipped|Luanda
# Processing record  195 and 16 skipped|Pasaquina
# Processing record  196 and 16 skipped|Nizwá
# Processing record  197 and 16 skipped|Saint George
# Processing record  198 and 16 skipped|Mar del Plata
# Processing record  199 and 16 skipped|Sistranda
# Processing record  200 and 16 skipped|Kruisfontein
# Processing record  201 and 16 skipped|Meulaboh
# Processing record  202 and 16 skipped|Sainte-Maxime
# Processing record  203 and 16 skipped|Kota Tinggi
# Processing record  204 and 16 skipped|Dauphin
# Processing record  205 and 16 skipped|Blackwater
# Processing record  206 and 16 skipped|Lüderitz
# Processing record  207 and 16 skipped|Torbay
# Processing record  208 and 16 skipped|Olinda
# Processing record  209 and 16 skipped|Dzemul
# City was not found. Skiping...
# Processing record  210 and 17 skipped|Lavrentiya
# Processing record  211 and 17 skipped|Wenling
# Processing record  212 and 17 skipped|Arraial do Cabo
# Processing record  213 and 17 skipped|Russell
# Processing record  214 and 17 skipped|Adrar
# Processing record  215 and 17 skipped|Nanortalik
# Processing record  216 and 17 skipped|Salihli
# City was not found. Skiping...
# Processing record  217 and 18 skipped|Krasnosel'kup
# Processing record  218 and 18 skipped|Severnyy
# Processing record  219 and 18 skipped|Ji’an
# Processing record  220 and 18 skipped|Bethel
# Processing record  221 and 18 skipped|Nokaneng
# Processing record  222 and 18 skipped|Camargo
# Processing record  223 and 18 skipped|Ust-Maya
# City was not found. Skiping...
# Processing record  224 and 19 skipped|Mundo Nuevo (Ojo de Agua)
# Processing record  225 and 19 skipped|Gorontalo
# Processing record  226 and 19 skipped|Provideniya
# Processing record  227 and 19 skipped|Abéché
# Processing record  228 and 19 skipped|Cherskiy
# Processing record  229 and 19 skipped|Bathsheba
# Processing record  230 and 19 skipped|Qaanaaq
# Processing record  231 and 19 skipped|Yuncheng
# Processing record  232 and 19 skipped|Tautira
# Processing record  233 and 19 skipped|Williston
# City was not found. Skiping...
# Processing record  234 and 20 skipped|Ancud
# Processing record  235 and 20 skipped|Mahébourg
# Processing record  236 and 20 skipped|Kaitangata
# Processing record  237 and 20 skipped|Flinders
# City was not found. Skiping...
# Processing record  238 and 21 skipped|Kavieng
# Processing record  239 and 21 skipped|Gayny
# Processing record  240 and 21 skipped|Airai
# Processing record  241 and 21 skipped|Vardø
# Processing record  242 and 21 skipped|Cabo San Lucas
# Processing record  243 and 21 skipped|Bongandanga
# Processing record  244 and 21 skipped|São João da Barra
# Processing record  245 and 21 skipped|Tiznit Province
# Processing record  246 and 21 skipped|Half Moon Bay
# Processing record  247 and 21 skipped|Nicoya
# Processing record  248 and 21 skipped|Stornoway
# Processing record  249 and 21 skipped|Bāneh
# Processing record  250 and 21 skipped|Kanniyākumāri
# Processing record  251 and 21 skipped|Awjilah
# City was not found. Skiping...
# Processing record  252 and 22 skipped|Oussouye
# Processing record  253 and 22 skipped|Kavaratti
# Processing record  254 and 22 skipped|Zhigansk
# Processing record  255 and 22 skipped|Itaueira
# Processing record  256 and 22 skipped|San Patricio
# Processing record  257 and 22 skipped|Jinxiang
# Processing record  258 and 22 skipped|Mae Sai
# Processing record  259 and 22 skipped|Kazachinskoye
# Processing record  260 and 22 skipped|East London
# Processing record  261 and 22 skipped|Waycross
# Processing record  262 and 22 skipped|Chegutu
# City was not found. Skiping...
# Processing record  263 and 23 skipped|Urucará
# Processing record  264 and 23 skipped|Cidreira
# Processing record  265 and 23 skipped|Rabat
# Processing record  266 and 23 skipped|Broken Hill
# Processing record  267 and 23 skipped|Ladário
# Processing record  268 and 23 skipped|Coyhaique
# Processing record  269 and 23 skipped|Plettenberg Bay
# Processing record  270 and 23 skipped|Basi
# Processing record  271 and 23 skipped|Broome
# Processing record  272 and 23 skipped|Ishigaki
# Processing record  273 and 23 skipped|Sungai Penuh
# Processing record  274 and 23 skipped|Bambous Virieux
# Processing record  275 and 23 skipped|Nouadhibou
# Processing record  276 and 23 skipped|Sabang
# Processing record  277 and 23 skipped|Cayenne
# Processing record  278 and 23 skipped|Hornepayne
# Processing record  279 and 23 skipped|Chateaubelair
# Processing record  280 and 23 skipped|Angoche
# Processing record  281 and 23 skipped|Ola
# Processing record  282 and 23 skipped|Netivot
# Processing record  283 and 23 skipped|Touros
# Processing record  284 and 23 skipped|Tessalit
# Processing record  285 and 23 skipped|Hanna
# Processing record  286 and 23 skipped|Ketchikan
# Processing record  287 and 23 skipped|Key West
# Processing record  288 and 23 skipped|Paamiut
# Processing record  289 and 23 skipped|Dawlatabad
# Processing record  290 and 23 skipped|Maku
# Processing record  291 and 23 skipped|Florianópolis
# Processing record  292 and 23 skipped|Husavik
# Processing record  293 and 23 skipped|Sittwe
# Processing record  294 and 23 skipped|Qaqortoq
# Processing record  295 and 23 skipped|Shingū
# Processing record  296 and 23 skipped|Wote
# Processing record  297 and 23 skipped|Stann Creek Town
# Processing record  298 and 23 skipped|Ilulissat
# Processing record  299 and 23 skipped|Saint Anthony
# Processing record  300 and 23 skipped|Goba
# City was not found. Skiping...
# Processing record  301 and 24 skipped|Kloulklubed
# Processing record  302 and 24 skipped|Griffith
# City was not found. Skiping...
# Processing record  303 and 25 skipped|Palana
# Processing record  304 and 25 skipped|Paraíso
# Processing record  305 and 25 skipped|Mazatlán
# Processing record  306 and 25 skipped|Frontera
# Processing record  307 and 25 skipped|Saint-Augustin
# Processing record  308 and 25 skipped|Talcahuano
# Processing record  309 and 25 skipped|Bouca
# Processing record  310 and 25 skipped|Dicabisagan
# Processing record  311 and 25 skipped|Kalianget
# Processing record  312 and 25 skipped|Bangkalan
# Processing record  313 and 25 skipped|Iracoubo
# Processing record  314 and 25 skipped|Manbij
# Processing record  315 and 25 skipped|Dhārchula
# Processing record  316 and 25 skipped|Caucayá
# Processing record  317 and 25 skipped|Avera
# Processing record  318 and 25 skipped|Shenzhen
# Processing record  319 and 25 skipped|Pangai
# Processing record  320 and 25 skipped|Otradnoye
# Processing record  321 and 25 skipped|Christchurch
# Processing record  322 and 25 skipped|Mandalgovi
# Processing record  323 and 25 skipped|Makkah al Mukarramah
# Processing record  324 and 25 skipped|Waipawa
# Processing record  325 and 25 skipped|Taltal
# Processing record  326 and 25 skipped|Naze
# Processing record  327 and 25 skipped|Beroroha
# City was not found. Skiping...
# Processing record  328 and 26 skipped|Okhotsk
# Processing record  329 and 26 skipped|San Jose
# Processing record  330 and 26 skipped|Mashivka
# Processing record  331 and 26 skipped|Tabat
# Processing record  332 and 26 skipped|Bitung
# Processing record  333 and 26 skipped|Hamilton
# Processing record  334 and 26 skipped|Olafsvik
# Processing record  335 and 26 skipped|Kaeo
# Processing record  336 and 26 skipped|Lakes Entrance
# Processing record  337 and 26 skipped|Luleå
# Processing record  338 and 26 skipped|Araguaína
# Processing record  339 and 26 skipped|Matucana
# Processing record  340 and 26 skipped|Bisalpur
# Processing record  341 and 26 skipped|Bāglung
# Processing record  342 and 26 skipped|Palmer
# Processing record  343 and 26 skipped|Tiksi
# Processing record  344 and 26 skipped|Umba
# Processing record  345 and 26 skipped|Auki
# City was not found. Skiping...
# Processing record  346 and 27 skipped|Chilmāri
# Processing record  347 and 27 skipped|Staunton
# Processing record  348 and 27 skipped|Chichimila
# Processing record  349 and 27 skipped|Jacqueville
# Processing record  350 and 27 skipped|Shache
# Processing record  351 and 27 skipped|Constitución
# Processing record  352 and 27 skipped|Atikokan
# Processing record  353 and 27 skipped|Eureka
# Processing record  354 and 27 skipped|Kokrek
# Processing record  355 and 27 skipped|Piedras Negras
# Processing record  356 and 27 skipped|Acapulco de Juárez
# Processing record  357 and 27 skipped|Paraná
# Processing record  358 and 27 skipped|Dingle
# Processing record  359 and 27 skipped|Pevek
# Processing record  360 and 27 skipped|Nuuk
# Processing record  361 and 27 skipped|Santa Cruz de la Sierra
# City was not found. Skiping...
# Processing record  362 and 28 skipped|Yangi Marg`ilon
# Processing record  363 and 28 skipped|La Ronge
# City was not found. Skiping...
# Processing record  364 and 29 skipped|Marzuq
# Processing record  365 and 29 skipped|Mont-Dore
# Processing record  366 and 29 skipped|Pointe Michel
# Processing record  367 and 29 skipped|Whakatane
# City was not found. Skiping...
# Processing record  368 and 30 skipped|Jiuquan
# Processing record  369 and 30 skipped|Ayan
# Processing record  370 and 30 skipped|Muros
# Processing record  371 and 30 skipped|Saint Augustine
# Processing record  372 and 30 skipped|Dunedin
# Processing record  373 and 30 skipped|Lunéville
# Processing record  374 and 30 skipped|Khani
# Processing record  375 and 30 skipped|Panama City
# Processing record  376 and 30 skipped|Eisenach
# Processing record  377 and 30 skipped|Boden
# City was not found. Skiping...
# Processing record  378 and 31 skipped|Itaguaí
# Processing record  379 and 31 skipped|Rafaela
# Processing record  380 and 31 skipped|Hualmay
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  381 and 33 skipped|Chu
# Processing record  382 and 33 skipped|Omsukchan
# Processing record  383 and 33 skipped|Riyadh
# Processing record  384 and 33 skipped|Laguna
# Processing record  385 and 33 skipped|Coahuayana Viejo
# Processing record  386 and 33 skipped|Valsamáta
# Processing record  387 and 33 skipped|Phan Thiet
# Processing record  388 and 33 skipped|Znamenskoye
# Processing record  389 and 33 skipped|Iqaluit
# Processing record  390 and 33 skipped|Damara
# Processing record  391 and 33 skipped|Hasaki
# City was not found. Skiping...
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  392 and 36 skipped|Tarko-Sale
# Processing record  393 and 36 skipped|Hauterive
# Processing record  394 and 36 skipped|Nemuro
# Processing record  395 and 36 skipped|Straumen
# Processing record  396 and 36 skipped|Ust'-Kan
# Processing record  397 and 36 skipped|Santana do Acaraú
# Processing record  398 and 36 skipped|Labuhan
# Processing record  399 and 36 skipped|Klichka
# City was not found. Skiping...
# Processing record  400 and 37 skipped|Tezu
# City was not found. Skiping...
# Processing record  401 and 38 skipped|Oga
# Processing record  402 and 38 skipped|Bertoua
# Processing record  403 and 38 skipped|Kurumkan
# Processing record  404 and 38 skipped|Qinzhou
# Processing record  405 and 38 skipped|Pacific Grove
# Processing record  406 and 38 skipped|Port Blair
# Processing record  407 and 38 skipped|Manggar
# Processing record  408 and 38 skipped|Antalaha
# Processing record  409 and 38 skipped|Foça
# Processing record  410 and 38 skipped|Hueytown
# Processing record  411 and 38 skipped|Oryol
# Processing record  412 and 38 skipped|Chifeng
# Processing record  413 and 38 skipped|Sawākin
# Processing record  414 and 38 skipped|Ibotirama
# Processing record  415 and 38 skipped|General Roca
# Processing record  416 and 38 skipped|Richmond
# Processing record  417 and 38 skipped|Shimoda
# Processing record  418 and 38 skipped|Longyearbyen
# Processing record  419 and 38 skipped|Klaksvík
# Processing record  420 and 38 skipped|Saskylakh
# Processing record  421 and 38 skipped|Kemijärvi
# Processing record  422 and 38 skipped|Belaya Gora
# Processing record  423 and 38 skipped|Pangnirtung
# Processing record  424 and 38 skipped|Hoi An
# Processing record  425 and 38 skipped|Chapais
# Processing record  426 and 38 skipped|Biltine
# Processing record  427 and 38 skipped|Sæby
# Processing record  428 and 38 skipped|Charter Township of Clinton
# Processing record  429 and 38 skipped|Edgewater
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  430 and 40 skipped|Te Anau
# Processing record  431 and 40 skipped|Bath
# Processing record  432 and 40 skipped|Normandin
# Processing record  433 and 40 skipped|Pangody
# Processing record  434 and 40 skipped|Roald
# Processing record  435 and 40 skipped|Sola
# Processing record  436 and 40 skipped|Gigmoto
# Processing record  437 and 40 skipped|La Rioja
# Processing record  438 and 40 skipped|Ust-Kuyga
# Processing record  439 and 40 skipped|Arrondissement de Saint-Denis
# Processing record  440 and 40 skipped|Vigrestad
# Processing record  441 and 40 skipped|Beidao
# Processing record  442 and 40 skipped|Mayumba
# City was not found. Skiping...
# Processing record  443 and 41 skipped|Kim
# Processing record  444 and 41 skipped|Ambalavao
# Processing record  445 and 41 skipped|Sinnamary
# Processing record  446 and 41 skipped|San Quintín
# Processing record  447 and 41 skipped|Port Hedland
# Processing record  448 and 41 skipped|Rawson
# City was not found. Skiping...
# Processing record  449 and 42 skipped|Paranhos
# City was not found. Skiping...
# Processing record  450 and 43 skipped|Östersund
# City was not found. Skiping...
# Processing record  451 and 44 skipped|Seoul
# Processing record  452 and 44 skipped|Kearney
# City was not found. Skiping...
# Processing record  453 and 45 skipped|Sioux Lookout
# Processing record  454 and 45 skipped|Chamba
# City was not found. Skiping...
# Processing record  455 and 46 skipped|Tilichiki
# Processing record  456 and 46 skipped|Ozubulu
# Processing record  457 and 46 skipped|Anadyr
# City was not found. Skiping...
# Processing record  458 and 47 skipped|Karratha
# Processing record  459 and 47 skipped|Faro
# Processing record  460 and 47 skipped|Zambezi
# Processing record  461 and 47 skipped|Caraquet
# Processing record  462 and 47 skipped|Verāval
# Processing record  463 and 47 skipped|Isla Mujeres
# Processing record  464 and 47 skipped|Sarangani
# Processing record  465 and 47 skipped|Yeppoon
# Processing record  466 and 47 skipped|Kiryat Gat
# Processing record  467 and 47 skipped|Usvyaty
# Processing record  468 and 47 skipped|Kuliyapitiya
# Processing record  469 and 47 skipped|Liepāja
# Processing record  470 and 47 skipped|Ciudad Guayana
# Processing record  471 and 47 skipped|Champerico
# Processing record  472 and 47 skipped|Moyo
# Processing record  473 and 47 skipped|Goroka
# City was not found. Skiping...
# Processing record  474 and 48 skipped|Leningradskiy
# Processing record  475 and 48 skipped|Shubarshi
# Processing record  476 and 48 skipped|Calderitas
# Processing record  477 and 48 skipped|Bubaque
# Processing record  478 and 48 skipped|Ust'-Ishim
# Processing record  479 and 48 skipped|Baní
# City was not found. Skiping...
# Processing record  480 and 49 skipped|Nieuw Amsterdam
# City was not found. Skiping...
# Processing record  481 and 50 skipped|Korla
# Processing record  482 and 50 skipped|Ostrovnoy
# Processing record  483 and 50 skipped|Ferme-Neuve
# Processing record  484 and 50 skipped|Kyzyl
# Processing record  485 and 50 skipped|Malbork
# Processing record  486 and 50 skipped|Turbat
# Processing record  487 and 50 skipped|Portland
# Processing record  488 and 50 skipped|Rancho Palos Verdes
# Processing record  489 and 50 skipped|Whitefish
# Processing record  490 and 50 skipped|Chernyshevskiy
# Processing record  491 and 50 skipped|Conceição da Barra
# Processing record  492 and 50 skipped|Santiago del Estero
# Processing record  493 and 50 skipped|Dhupgāri
# Processing record  494 and 50 skipped|Distrikt Brokopondo
# Processing record  495 and 50 skipped|Basco
# Processing record  496 and 50 skipped|Hanmer Springs
# Processing record  497 and 50 skipped|Nova Era
# Processing record  498 and 50 skipped|Marabu
# City was not found. Skiping...
# Processing record  499 and 51 skipped|Mūl
# Processing record  500 and 51 skipped|Tazovsky
# Processing record  501 and 51 skipped|Oktyabr'skiy
# Processing record  502 and 51 skipped|Qasigiannguit
# City was not found. Skiping...
# Processing record  503 and 52 skipped|Ixtapa
# Processing record  504 and 52 skipped|Tianpeng
# Processing record  505 and 52 skipped|Wanning
# Processing record  506 and 52 skipped|Kieta
# Processing record  507 and 52 skipped|Popondetta
# Processing record  508 and 52 skipped|Presidencia Roque Sáenz Peña
# Processing record  509 and 52 skipped|Kysyl-Syr
# Processing record  510 and 52 skipped|Isangel
# Processing record  511 and 52 skipped|Rumford
# Processing record  512 and 52 skipped|Aseri
# Processing record  513 and 52 skipped|Oranjemund
# Processing record  514 and 52 skipped|Kishtwār
# Processing record  515 and 52 skipped|Bow Island
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  516 and 54 skipped|Praia
# Processing record  517 and 54 skipped|Port-Gentil
# Processing record  518 and 54 skipped|Kharan
# Processing record  519 and 54 skipped|Kamaishi
# Processing record  520 and 54 skipped|Santa Isabel Rio Negro
# Processing record  521 and 54 skipped|Darhan
# Processing record  522 and 54 skipped|Klyuchi
# Processing record  523 and 54 skipped|Lorengau
# Processing record  524 and 54 skipped|Ratholo
# Processing record  525 and 54 skipped|Bilma
# Processing record  526 and 54 skipped|Ţahţā
# Processing record  527 and 54 skipped|San Rafael
# Processing record  528 and 54 skipped|Bago
# Processing record  529 and 54 skipped|Shaowu
# Processing record  530 and 54 skipped|Ponta Delgada
# Processing record  531 and 54 skipped|Saquarema
# Processing record  532 and 54 skipped|Calvinia
# Processing record  533 and 54 skipped|Menongue
# Processing record  534 and 54 skipped|Cortez
# Processing record  535 and 54 skipped|Dargaville
# Processing record  536 and 54 skipped|José Bonifácio
# Processing record  537 and 54 skipped|Quang Ngai
# Processing record  538 and 54 skipped|Gewanē
# Processing record  539 and 54 skipped|Caravelas
# Processing record  540 and 54 skipped|Three Hills
# Processing record  541 and 54 skipped|Torrevieja
# Processing record  542 and 54 skipped|Cedar City
# Processing record  543 and 54 skipped|Inhambane
# Processing record  544 and 54 skipped|Porbandar
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  545 and 56 skipped|Larsnes
# Processing record  546 and 56 skipped|Sorada
# Processing record  547 and 56 skipped|Yining
# Processing record  548 and 56 skipped|Maceió
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  549 and 58 skipped|Gimli
# Processing record  550 and 58 skipped|Lachute
# Processing record  551 and 58 skipped|Acajutla
# Processing record  552 and 58 skipped|Sirte
# Processing record  553 and 58 skipped|Karangampel
# Processing record  554 and 58 skipped|Muisne
# Processing record  555 and 58 skipped|Ubari
# Processing record  556 and 58 skipped|Saint-Joseph
# Processing record  557 and 58 skipped|Moree
# Processing record  558 and 58 skipped|São Brás de Alportel
# Processing record  559 and 58 skipped|Zhuanghe
# Processing record  560 and 58 skipped|Letterkenny
# Processing record  561 and 58 skipped|Veinticinco de Mayo
# Processing record  562 and 58 skipped|Palmas
# Processing record  563 and 58 skipped|Goderich
# City was not found. Skiping...
# Processing record  564 and 59 skipped|Andenes
# Processing record  565 and 59 skipped|Mount Isa
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame(weather_dic)
weather_data.to_csv(r'../output_data/cities.csv',index=False, header=True)

weather_data.head()
# Out:
#    City ID      City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        0    Castro          36      BR  1592337531        79 -24.79  -50.01
# 1        1     Kapaa          75      US  1592337531        83  22.08 -159.32
# 2        2   Rikitea          90      PF  1592337531        79 -23.12 -134.97
# 3        3   Mataura         100      NZ  1592337531        83 -46.19  168.86
# 4        4  Tasiilaq         100      GL  1592337532        94  65.61  -37.64
#
#    Max Temp  Wind Speed
# 0     18.20        2.01
# 1     26.00        6.70
# 2     24.21        6.36
# 3      8.50        2.27
# 4      1.00        6.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs. Temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")

# Create a timestamp for today
today_date = pd.Timestamp("today").strftime("%m/%d/%Y")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({today_date})")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.ylim(-5, 45)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({today_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 200)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", alpha=1, edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({today_date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 110)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({today_date})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.ylim(-2, 40)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
