# %% [markdown]
# # WeatherPy
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ##### 1. Here we can see the highest temperature around equator line, which is 0 Latitude. It is known that temperature is getting higher by moving towards equator.

# %% [markdown]
# ##### 2. There were not  observed crucial relationship between humidity, cloudness and wind speed vs. Latitude in this dataset.

# %% [markdown]
# ###### 3. Science reasearch tought us that cloudiness usually higher around -60 Latitude which is South 60 degree, but this dataset can't prove that.

# %% [markdown]
# * Metric units used despite on instruction requirement of imperial, if imperial is required in "Perform API calls" line  units variable value could be changed to imperial. Otherwise expect all results in metric units.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 581

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

number = -1
skip = 0
city_name=[]
temp =[]
cloud=[]
country=[]
date=[]
hum=[]
latitude=[]
long=[]
wind=[]
num =[]
print("Beginning of data collection")
print("--------------------------------")
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        temp.append(response['main']['temp_max'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        hum.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        number+=1
        num.append(number)
        print("Processing record  " +str(number+1)+ " and " + str(skip) + " skipped" + "|" + response['name'])
    except KeyError:
        skip+=1
        print(f"City was not found. Skiping... ")
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
weather_dic = {
    "City ID": num,"City": city_name, "Cloudiness":cloud, "Country":country, "Date": date, 
    "Humidity": hum, "Lat":latitude, "Lng":long, "Max Temp": temp,"Wind Speed": wind  
}
# Out:
# Beginning of data collection
# --------------------------------
# Processing record  1 and 0 skipped|Bluff
# City was not found. Skiping...
# Processing record  2 and 1 skipped|Karpogory
# Processing record  3 and 1 skipped|Albany
# Processing record  4 and 1 skipped|Port Elizabeth
# Processing record  5 and 1 skipped|Ushuaia
# Processing record  6 and 1 skipped|Niihama
# Processing record  7 and 1 skipped|Arkadak
# Processing record  8 and 1 skipped|Geraldton
# Processing record  9 and 1 skipped|Chui
# Processing record  10 and 1 skipped|Upernavik
# Processing record  11 and 1 skipped|Mahébourg
# Processing record  12 and 1 skipped|Kaitangata
# Processing record  13 and 1 skipped|Avarua
# Processing record  14 and 1 skipped|Cabo San Lucas
# Processing record  15 and 1 skipped|Jati
# Processing record  16 and 1 skipped|Chernyshevskiy
# Processing record  17 and 1 skipped|Punta Arenas
# Processing record  18 and 1 skipped|Carnarvon
# Processing record  19 and 1 skipped|Grand Gaube
# Processing record  20 and 1 skipped|Terrace
# Processing record  21 and 1 skipped|Prince Rupert
# Processing record  22 and 1 skipped|Yatou
# Processing record  23 and 1 skipped|Buala
# Processing record  24 and 1 skipped|Busselton
# City was not found. Skiping...
# Processing record  25 and 2 skipped|Virginia Beach
# Processing record  26 and 2 skipped|Ponta do Sol
# Processing record  27 and 2 skipped|Atuona
# Processing record  28 and 2 skipped|Mataura
# Processing record  29 and 2 skipped|Ancud
# Processing record  30 and 2 skipped|Seabra
# Processing record  31 and 2 skipped|Nikolskoye
# Processing record  32 and 2 skipped|Bredasdorp
# Processing record  33 and 2 skipped|Mitú
# Processing record  34 and 2 skipped|Cape Town
# Processing record  35 and 2 skipped|Iqaluit
# Processing record  36 and 2 skipped|Aitape
# City was not found. Skiping...
# Processing record  37 and 3 skipped|Rikitea
# Processing record  38 and 3 skipped|Jamestown
# Processing record  39 and 3 skipped|Bengkulu
# City was not found. Skiping...
# Processing record  40 and 4 skipped|Oodweyne
# Processing record  41 and 4 skipped|Hirara
# Processing record  42 and 4 skipped|Mfou
# Processing record  43 and 4 skipped|Cairns
# Processing record  44 and 4 skipped|Vaini
# Processing record  45 and 4 skipped|El Carmen
# Processing record  46 and 4 skipped|Nola
# City was not found. Skiping...
# Processing record  47 and 5 skipped|Kapaa
# Processing record  48 and 5 skipped|São Filipe
# Processing record  49 and 5 skipped|Motygino
# Processing record  50 and 5 skipped|Lagoa
# Processing record  51 and 5 skipped|Semey
# Processing record  52 and 5 skipped|Butaritari
# Processing record  53 and 5 skipped|Samarai
# Processing record  54 and 5 skipped|Barrow
# Processing record  55 and 5 skipped|Townsville
# Processing record  56 and 5 skipped|Qaanaaq
# Processing record  57 and 5 skipped|Osypenko
# Processing record  58 and 5 skipped|Hong Kong
# City was not found. Skiping...
# Processing record  59 and 6 skipped|Saskylakh
# Processing record  60 and 6 skipped|Longyearbyen
# Processing record  61 and 6 skipped|Langsa
# Processing record  62 and 6 skipped|Omboué
# Processing record  63 and 6 skipped|Antofagasta
# Processing record  64 and 6 skipped|Saint George
# Processing record  65 and 6 skipped|Ribeira Grande
# Processing record  66 and 6 skipped|Hilo
# Processing record  67 and 6 skipped|Mehamn
# Processing record  68 and 6 skipped|Sitka
# Processing record  69 and 6 skipped|Balasore
# Processing record  70 and 6 skipped|Farmington
# Processing record  71 and 6 skipped|Mangan
# Processing record  72 and 6 skipped|Bethel
# Processing record  73 and 6 skipped|Järvenpää
# Processing record  74 and 6 skipped|New Norfolk
# Processing record  75 and 6 skipped|Port Alfred
# Processing record  76 and 6 skipped|Thompson
# Processing record  77 and 6 skipped|Inírida
# Processing record  78 and 6 skipped|Katsuura
# Processing record  79 and 6 skipped|Sydney
# Processing record  80 and 6 skipped|Urubichá
# Processing record  81 and 6 skipped|Nakonde
# Processing record  82 and 6 skipped|Severo-Kuril'sk
# Processing record  83 and 6 skipped|Maţāy
# Processing record  84 and 6 skipped|Adrar
# Processing record  85 and 6 skipped|Medicine Hat
# Processing record  86 and 6 skipped|Khatanga
# Processing record  87 and 6 skipped|Grindavik
# Processing record  88 and 6 skipped|Serebryansk
# Processing record  89 and 6 skipped|Leningradskiy
# Processing record  90 and 6 skipped|Sinaloa
# City was not found. Skiping...
# Processing record  91 and 7 skipped|Faya
# Processing record  92 and 7 skipped|Saint Paul Harbor
# Processing record  93 and 7 skipped|Salinópolis
# City was not found. Skiping...
# Processing record  94 and 8 skipped|Storforshei
# Processing record  95 and 8 skipped|Erdenet
# Processing record  96 and 8 skipped|Kavaratti
# Processing record  97 and 8 skipped|Paamiut
# City was not found. Skiping...
# Processing record  98 and 9 skipped|Šilutė
# Processing record  99 and 9 skipped|Port Hardy
# Processing record  100 and 9 skipped|Hofn
# City was not found. Skiping...
# Processing record  101 and 10 skipped|Mar del Plata
# Processing record  102 and 10 skipped|Alofi
# Processing record  103 and 10 skipped|Mitsamiouli
# Processing record  104 and 10 skipped|Pareora
# Processing record  105 and 10 skipped|Kondinskoye
# Processing record  106 and 10 skipped|Provideniya
# Processing record  107 and 10 skipped|Yerbogachën
# Processing record  108 and 10 skipped|Tessalit
# Processing record  109 and 10 skipped|Zhongshu
# Processing record  110 and 10 skipped|Beroroha
# City was not found. Skiping...
# Processing record  111 and 11 skipped|Tasiilaq
# Processing record  112 and 11 skipped|Beloha
# Processing record  113 and 11 skipped|Hithadhoo
# City was not found. Skiping...
# Processing record  114 and 12 skipped|Dingle
# Processing record  115 and 12 skipped|Arrondissement du Havre
# Processing record  116 and 12 skipped|Yellowknife
# Processing record  117 and 12 skipped|Lloydminster
# Processing record  118 and 12 skipped|Cayenne
# Processing record  119 and 12 skipped|Port Blair
# Processing record  120 and 12 skipped|Chauk
# Processing record  121 and 12 skipped|Balotra
# Processing record  122 and 12 skipped|Arraial do Cabo
# Processing record  123 and 12 skipped|Mizdah
# City was not found. Skiping...
# Processing record  124 and 13 skipped|Kanniyākumāri
# Processing record  125 and 13 skipped|Bethal
# Processing record  126 and 13 skipped|Mossamedes
# Processing record  127 and 13 skipped|Puri
# Processing record  128 and 13 skipped|The Valley
# City was not found. Skiping...
# Processing record  129 and 14 skipped|Kloulklubed
# Processing record  130 and 14 skipped|Udachny
# Processing record  131 and 14 skipped|Bambous Virieux
# Processing record  132 and 14 skipped|Harmanli
# Processing record  133 and 14 skipped|Birobidzhan
# Processing record  134 and 14 skipped|Teguise
# Processing record  135 and 14 skipped|Half Moon Bay
# Processing record  136 and 14 skipped|Yangi Marg`ilon
# City was not found. Skiping...
# Processing record  137 and 15 skipped|Nānākuli
# Processing record  138 and 15 skipped|Na Wa
# Processing record  139 and 15 skipped|Saint-Ambroise
# Processing record  140 and 15 skipped|Kruisfontein
# Processing record  141 and 15 skipped|Hobart
# Processing record  142 and 15 skipped|Malye Derbety
# Processing record  143 and 15 skipped|Nara
# City was not found. Skiping...
# Processing record  144 and 16 skipped|Nelson Bay
# Processing record  145 and 16 skipped|Hermanus
# Processing record  146 and 16 skipped|Srednekolymsk
# Processing record  147 and 16 skipped|Olafsvik
# Processing record  148 and 16 skipped|Nhulunbuy
# Processing record  149 and 16 skipped|Kodinsk
# Processing record  150 and 16 skipped|Tuktoyaktuk
# Processing record  151 and 16 skipped|Saint-Philippe
# Processing record  152 and 16 skipped|Puerto Ayora
# Processing record  153 and 16 skipped|Touros
# Processing record  154 and 16 skipped|Isangel
# Processing record  155 and 16 skipped|Doumé
# Processing record  156 and 16 skipped|George Town
# Processing record  157 and 16 skipped|Sri Aman
# Processing record  158 and 16 skipped|Kulhudhuffushi
# Processing record  159 and 16 skipped|Sirte
# Processing record  160 and 16 skipped|Vila
# Processing record  161 and 16 skipped|Lebu
# Processing record  162 and 16 skipped|Moskovskiy
# Processing record  163 and 16 skipped|Hambantota
# Processing record  164 and 16 skipped|Faanui
# Processing record  165 and 16 skipped|Malbork
# City was not found. Skiping...
# Processing record  166 and 17 skipped|Cidreira
# Processing record  167 and 17 skipped|Svetlaya
# Processing record  168 and 17 skipped|Charters Towers
# Processing record  169 and 17 skipped|Corpus Christi
# City was not found. Skiping...
# Processing record  170 and 18 skipped|La Ronge
# Processing record  171 and 18 skipped|Santo Amaro da Imperatriz
# Processing record  172 and 18 skipped|Evensk
# Processing record  173 and 18 skipped|Kamennogorsk
# Processing record  174 and 18 skipped|Port Lincoln
# Processing record  175 and 18 skipped|Dunedin
# Processing record  176 and 18 skipped|Mananara
# Processing record  177 and 18 skipped|Tomatlán
# Processing record  178 and 18 skipped|Vardø
# Processing record  179 and 18 skipped|Challans
# Processing record  180 and 18 skipped|Anloga
# Processing record  181 and 18 skipped|Manokwari
# Processing record  182 and 18 skipped|Bandarbeyla
# City was not found. Skiping...
# Processing record  183 and 19 skipped|Honiara
# Processing record  184 and 19 skipped|Río Gallegos
# Processing record  185 and 19 skipped|Beibei
# City was not found. Skiping...
# Processing record  186 and 20 skipped|Torbay
# Processing record  187 and 20 skipped|Ko Samui
# Processing record  188 and 20 skipped|Tiksi
# Processing record  189 and 20 skipped|Castro
# Processing record  190 and 20 skipped|Nuuk
# Processing record  191 and 20 skipped|Kavieng
# Processing record  192 and 20 skipped|Ýpsonas
# Processing record  193 and 20 skipped|Altay
# City was not found. Skiping...
# Processing record  194 and 21 skipped|Peremyshl'
# Processing record  195 and 21 skipped|Abu Kamal
# Processing record  196 and 21 skipped|Esperance
# Processing record  197 and 21 skipped|Mahanje
# Processing record  198 and 21 skipped|Buluang
# City was not found. Skiping...
# Processing record  199 and 22 skipped|Leh
# Processing record  200 and 22 skipped|Makakilo City
# Processing record  201 and 22 skipped|Talnakh
# Processing record  202 and 22 skipped|Vung Tau
# Processing record  203 and 22 skipped|Poum
# City was not found. Skiping...
# Processing record  204 and 23 skipped|Haines Junction
# Processing record  205 and 23 skipped|Juneau
# Processing record  206 and 23 skipped|Cherskiy
# Processing record  207 and 23 skipped|Seredka
# City was not found. Skiping...
# Processing record  208 and 24 skipped|Lavrentiya
# City was not found. Skiping...
# Processing record  209 and 25 skipped|Tautira
# Processing record  210 and 25 skipped|San Quintín
# Processing record  211 and 25 skipped|Manadhoo
# City was not found. Skiping...
# Processing record  212 and 26 skipped|Abbeville
# Processing record  213 and 26 skipped|Goderich
# Processing record  214 and 26 skipped|Kilinochchi
# Processing record  215 and 26 skipped|Scărişoara
# City was not found. Skiping...
# Processing record  216 and 27 skipped|Siguiri
# Processing record  217 and 27 skipped|Dikson
# Processing record  218 and 27 skipped|Saldanha
# Processing record  219 and 27 skipped|Oriximiná
# Processing record  220 and 27 skipped|Barcelos
# Processing record  221 and 27 skipped|Hay River
# Processing record  222 and 27 skipped|Flinders
# Processing record  223 and 27 skipped|Chicama
# Processing record  224 and 27 skipped|Pacific Grove
# City was not found. Skiping...
# Processing record  225 and 28 skipped|Pisco
# Processing record  226 and 28 skipped|Shingū
# Processing record  227 and 28 skipped|Kenai
# Processing record  228 and 28 skipped|Havelock
# Processing record  229 and 28 skipped|Havøysund
# Processing record  230 and 28 skipped|East London
# Processing record  231 and 28 skipped|Ararat
# Processing record  232 and 28 skipped|Halifax
# Processing record  233 and 28 skipped|Bathsheba
# Processing record  234 and 28 skipped|Lüderitz
# Processing record  235 and 28 skipped|Kharan
# Processing record  236 and 28 skipped|Vila Velha
# Processing record  237 and 28 skipped|Shubarshi
# City was not found. Skiping...
# Processing record  238 and 29 skipped|Zemetchino
# Processing record  239 and 29 skipped|Bullhead City
# Processing record  240 and 29 skipped|Tal'menka
# Processing record  241 and 29 skipped|Laas
# Processing record  242 and 29 skipped|Pandan
# Processing record  243 and 29 skipped|Prado
# Processing record  244 and 29 skipped|Santa María del Río
# Processing record  245 and 29 skipped|Westport
# Processing record  246 and 29 skipped|Votkinsk
# Processing record  247 and 29 skipped|Niğde
# Processing record  248 and 29 skipped|Nuevo Progreso
# Processing record  249 and 29 skipped|Kununurra
# Processing record  250 and 29 skipped|Clyde River
# Processing record  251 and 29 skipped|Minna
# Processing record  252 and 29 skipped|Bontang
# Processing record  253 and 29 skipped|Tuatapere
# Processing record  254 and 29 skipped|Grafton
# Processing record  255 and 29 skipped|Najrān
# City was not found. Skiping...
# Processing record  256 and 30 skipped|San Andrés
# Processing record  257 and 30 skipped|Pierre
# Processing record  258 and 30 skipped|Panguna
# Processing record  259 and 30 skipped|Hokitika
# Processing record  260 and 30 skipped|Dandong
# Processing record  261 and 30 skipped|Meulaboh
# Processing record  262 and 30 skipped|Belmonte
# Processing record  263 and 30 skipped|Kumul
# Processing record  264 and 30 skipped|Mahon
# Processing record  265 and 30 skipped|San Jerónimo
# Processing record  266 and 30 skipped|Lagunas
# Processing record  267 and 30 skipped|Jutaí
# Processing record  268 and 30 skipped|Quelimane
# Processing record  269 and 30 skipped|Mana
# Processing record  270 and 30 skipped|San Patricio
# Processing record  271 and 30 skipped|Lompoc
# Processing record  272 and 30 skipped|Bay Roberts
# Processing record  273 and 30 skipped|Klaksvík
# Processing record  274 and 30 skipped|Santa Rosa
# Processing record  275 and 30 skipped|Cabinda
# Processing record  276 and 30 skipped|Jumla
# Processing record  277 and 30 skipped|Rio Grande
# Processing record  278 and 30 skipped|Husavik
# Processing record  279 and 30 skipped|Lorengau
# Processing record  280 and 30 skipped|Kilindoni
# Processing record  281 and 30 skipped|Karratha
# Processing record  282 and 30 skipped|Shakawe
# Processing record  283 and 30 skipped|Ayan
# Processing record  284 and 30 skipped|Sironj
# Processing record  285 and 30 skipped|Ilebo
# Processing record  286 and 30 skipped|Kologriv
# Processing record  287 and 30 skipped|Venado Tuerto
# Processing record  288 and 30 skipped|Taltal
# Processing record  289 and 30 skipped|Petauke
# Processing record  290 and 30 skipped|Narsaq
# Processing record  291 and 30 skipped|Sekoma
# Processing record  292 and 30 skipped|Westerland
# Processing record  293 and 30 skipped|Uglekamensk
# Processing record  294 and 30 skipped|Seymchan
# Processing record  295 and 30 skipped|Gold Coast
# Processing record  296 and 30 skipped|Vao
# Processing record  297 and 30 skipped|Coahuayana Viejo
# Processing record  298 and 30 skipped|Tabou
# Processing record  299 and 30 skipped|Strunino
# Processing record  300 and 30 skipped|Nabire
# Processing record  301 and 30 skipped|Kremenki
# Processing record  302 and 30 skipped|Karoi
# Processing record  303 and 30 skipped|Grand-Santi
# Processing record  304 and 30 skipped|Lakes Entrance
# Processing record  305 and 30 skipped|Kenora
# Processing record  306 and 30 skipped|Mt. Pleasant
# Processing record  307 and 30 skipped|Askiz
# Processing record  308 and 30 skipped|Airai
# Processing record  309 and 30 skipped|Presidencia Roque Sáenz Peña
# City was not found. Skiping...
# Processing record  310 and 31 skipped|Goiatuba
# Processing record  311 and 31 skipped|Thabazimbi
# Processing record  312 and 31 skipped|Cururupu
# Processing record  313 and 31 skipped|Saýat
# Processing record  314 and 31 skipped|Semnan
# Processing record  315 and 31 skipped|Yamada
# Processing record  316 and 31 skipped|Örnsköldsvik
# Processing record  317 and 31 skipped|Bor
# Processing record  318 and 31 skipped|Shitanjing
# Processing record  319 and 31 skipped|Rome
# Processing record  320 and 31 skipped|Mount Gambier
# Processing record  321 and 31 skipped|Baní
# Processing record  322 and 31 skipped|Loíza
# Processing record  323 and 31 skipped|Beringovskiy
# City was not found. Skiping...
# Processing record  324 and 32 skipped|Broome
# Processing record  325 and 32 skipped|Sergeevka
# Processing record  326 and 32 skipped|Östersund
# Processing record  327 and 32 skipped|Pittsburg
# Processing record  328 and 32 skipped|Stornoway
# Processing record  329 and 32 skipped|Waipawa
# Processing record  330 and 32 skipped|Nome
# Processing record  331 and 32 skipped|San Miguel de Tucumán
# Processing record  332 and 32 skipped|Chapais
# Processing record  333 and 32 skipped|Mutoko
# Processing record  334 and 32 skipped|Bluefields
# Processing record  335 and 32 skipped|Pochutla
# Processing record  336 and 32 skipped|Rutana Province
# Processing record  337 and 32 skipped|Boyolangu
# Processing record  338 and 32 skipped|Yucca Valley
# Processing record  339 and 32 skipped|Mastic Beach
# Processing record  340 and 32 skipped|Asău
# Processing record  341 and 32 skipped|Lata
# Processing record  342 and 32 skipped|Sisimiut
# Processing record  343 and 32 skipped|Carbonia
# Processing record  344 and 32 skipped|Sumter
# Processing record  345 and 32 skipped|Salalah
# Processing record  346 and 32 skipped|Rawson
# City was not found. Skiping...
# Processing record  347 and 33 skipped|Kiryat Gat
# Processing record  348 and 33 skipped|Huilong
# Processing record  349 and 33 skipped|Caravelas
# Processing record  350 and 33 skipped|Fort Nelson
# Processing record  351 and 33 skipped|Aragarças
# Processing record  352 and 33 skipped|Kinkala
# Processing record  353 and 33 skipped|Kirkuk
# Processing record  354 and 33 skipped|Ebenthal
# Processing record  355 and 33 skipped|Rundu
# Processing record  356 and 33 skipped|Crotone
# Processing record  357 and 33 skipped|Vammala
# Processing record  358 and 33 skipped|Kosovo Polje
# Processing record  359 and 33 skipped|Verkhnetulomskiy
# Processing record  360 and 33 skipped|Zholymbet
# Processing record  361 and 33 skipped|Ugoofaaru
# Processing record  362 and 33 skipped|Koz'modem'yansk
# Processing record  363 and 33 skipped|Yining
# Processing record  364 and 33 skipped|Macomb
# Processing record  365 and 33 skipped|Kingman
# Processing record  366 and 33 skipped|Moctezuma
# Processing record  367 and 33 skipped|Okha
# Processing record  368 and 33 skipped|Fortuna
# Processing record  369 and 33 skipped|Córdoba
# Processing record  370 and 33 skipped|St. George's
# Processing record  371 and 33 skipped|Bilibino
# Processing record  372 and 33 skipped|Kaeo
# Processing record  373 and 33 skipped|Sokone
# Processing record  374 and 33 skipped|Vestmanna
# Processing record  375 and 33 skipped|Souillac
# Processing record  376 and 33 skipped|Zhangye
# Processing record  377 and 33 skipped|Kushima
# Processing record  378 and 33 skipped|Trincomalee
# Processing record  379 and 33 skipped|Ozinki
# Processing record  380 and 33 skipped|Tokur
# Processing record  381 and 33 skipped|Luzhou
# Processing record  382 and 33 skipped|Margate
# Processing record  383 and 33 skipped|Mandalgovi
# Processing record  384 and 33 skipped|Catherinas Lust
# Processing record  385 and 33 skipped|Venice
# Processing record  386 and 33 skipped|Codrington
# Processing record  387 and 33 skipped|Chokurdakh
# Processing record  388 and 33 skipped|Douala
# Processing record  389 and 33 skipped|Ikalamavony
# Processing record  390 and 33 skipped|Beyneu
# Processing record  391 and 33 skipped|San Lazaro
# Processing record  392 and 33 skipped|San Ramon
# Processing record  393 and 33 skipped|Norman Wells
# Processing record  394 and 33 skipped|Shache
# Processing record  395 and 33 skipped|Shenjiamen
# Processing record  396 and 33 skipped|Henties Bay
# Processing record  397 and 33 skipped|Vidim
# Processing record  398 and 33 skipped|Yar-Sale
# Processing record  399 and 33 skipped|Tahe
# Processing record  400 and 33 skipped|Dawson Creek
# Processing record  401 and 33 skipped|Nivala
# Processing record  402 and 33 skipped|Kieta
# Processing record  403 and 33 skipped|Lubango
# Processing record  404 and 33 skipped|Nanortalik
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  405 and 35 skipped|Catuday
# Processing record  406 and 35 skipped|Tommot
# Processing record  407 and 35 skipped|Peniche
# Processing record  408 and 35 skipped|Shirokiy
# Processing record  409 and 35 skipped|Jacareacanga
# Processing record  410 and 35 skipped|Aklavik
# Processing record  411 and 35 skipped|Igarka
# Processing record  412 and 35 skipped|Sur
# Processing record  413 and 35 skipped|Mareeba
# Processing record  414 and 35 skipped|Kapoeta
# Processing record  415 and 35 skipped|Zaozyornoye
# Processing record  416 and 35 skipped|Yenagoa
# Processing record  417 and 35 skipped|Concepción del Uruguay
# Processing record  418 and 35 skipped|Flagstaff
# Processing record  419 and 35 skipped|Kahului
# Processing record  420 and 35 skipped|Batemans Bay
# Processing record  421 and 35 skipped|Durban
# Processing record  422 and 35 skipped|Sayyan
# Processing record  423 and 35 skipped|Vikulovo
# Processing record  424 and 35 skipped|Dustlik
# Processing record  425 and 35 skipped|Ābdānān
# Processing record  426 and 35 skipped|Athani
# Processing record  427 and 35 skipped|Noumea
# Processing record  428 and 35 skipped|Sikeston
# Processing record  429 and 35 skipped|Eirunepé
# Processing record  430 and 35 skipped|Key West
# Processing record  431 and 35 skipped|Staroshcherbinovskaya
# Processing record  432 and 35 skipped|Ketchikan
# Processing record  433 and 35 skipped|Victor Harbor
# Processing record  434 and 35 skipped|Jiayuguan City
# Processing record  435 and 35 skipped|Pevek
# Processing record  436 and 35 skipped|Ereymentau
# Processing record  437 and 35 skipped|Los Llanos de Aridane
# Processing record  438 and 35 skipped|Korla
# Processing record  439 and 35 skipped|Flin Flon
# Processing record  440 and 35 skipped|Ostrovnoy
# City was not found. Skiping...
# Processing record  441 and 36 skipped|Biak
# Processing record  442 and 36 skipped|Erenhot
# Processing record  443 and 36 skipped|Lichuan
# Processing record  444 and 36 skipped|Strezhevoy
# Processing record  445 and 36 skipped|Tandil
# City was not found. Skiping...
# Processing record  446 and 37 skipped|Alyangula
# Processing record  447 and 37 skipped|Nouadhibou
# Processing record  448 and 37 skipped|Liverpool
# Processing record  449 and 37 skipped|Kailua
# Processing record  450 and 37 skipped|Bombarral
# Processing record  451 and 37 skipped|Dondo
# Processing record  452 and 37 skipped|Pucallpa
# Processing record  453 and 37 skipped|Bonthe
# Processing record  454 and 37 skipped|Médéa
# Processing record  455 and 37 skipped|Port Shepstone
# Processing record  456 and 37 skipped|Elk Plain
# Processing record  457 and 37 skipped|Yulara
# Processing record  458 and 37 skipped|Lukovetskiy
# Processing record  459 and 37 skipped|Kyshtovka
# Processing record  460 and 37 skipped|Berdychiv
# Processing record  461 and 37 skipped|Lumsden
# Processing record  462 and 37 skipped|Katy
# Processing record  463 and 37 skipped|Furth im Wald
# Processing record  464 and 37 skipped|Sakata
# Processing record  465 and 37 skipped|Pimentel
# Processing record  466 and 37 skipped|North Bend
# Processing record  467 and 37 skipped|Moog
# Processing record  468 and 37 skipped|Megion
# Processing record  469 and 37 skipped|São José da Coroa Grande
# Processing record  470 and 37 skipped|Kranuan
# Processing record  471 and 37 skipped|Haimen
# Processing record  472 and 37 skipped|Batagay-Alyta
# Processing record  473 and 37 skipped|Szczytno
# Processing record  474 and 37 skipped|São João da Barra
# Processing record  475 and 37 skipped|Caramay
# Processing record  476 and 37 skipped|Wiarton
# Processing record  477 and 37 skipped|Okakarara
# Processing record  478 and 37 skipped|Camacha
# Processing record  479 and 37 skipped|Ust'-Ilimsk
# Processing record  480 and 37 skipped|Maniitsoq
# City was not found. Skiping...
# Processing record  481 and 38 skipped|Japura
# City was not found. Skiping...
# Processing record  482 and 39 skipped|Dūkštas
# Processing record  483 and 39 skipped|Turkmenabat
# Processing record  484 and 39 skipped|Portland
# Processing record  485 and 39 skipped|Bagdarin
# Processing record  486 and 39 skipped|Nassau
# Processing record  487 and 39 skipped|Sobolevo
# Processing record  488 and 39 skipped|Hasaki
# Processing record  489 and 39 skipped|Port Macquarie
# Processing record  490 and 39 skipped|Qinhuangdao
# Processing record  491 and 39 skipped|Ukiah
# Processing record  492 and 39 skipped|Tavricheskoye
# Processing record  493 and 39 skipped|Lundazi
# Processing record  494 and 39 skipped|Zyryanka
# Processing record  495 and 39 skipped|Waingapu
# Processing record  496 and 39 skipped|Bundaberg
# Processing record  497 and 39 skipped|Tawang Town
# Processing record  498 and 39 skipped|Ola
# Processing record  499 and 39 skipped|Carupano
# Processing record  500 and 39 skipped|Dukat
# Processing record  501 and 39 skipped|Chitipa
# Processing record  502 and 39 skipped|Ndélé
# Processing record  503 and 39 skipped|Mayo
# Processing record  504 and 39 skipped|Porteirinha
# Processing record  505 and 39 skipped|Erzin
# Processing record  506 and 39 skipped|Sambava
# City was not found. Skiping...
# Processing record  507 and 40 skipped|Pljevlja
# Processing record  508 and 40 skipped|Noyabrsk
# Processing record  509 and 40 skipped|Boddam
# City was not found. Skiping...
# Processing record  510 and 41 skipped|Camargo
# Processing record  511 and 41 skipped|Felipe Carrillo Puerto
# City was not found. Skiping...
# Processing record  512 and 42 skipped|Bud
# Processing record  513 and 42 skipped|Cortez
# City was not found. Skiping...
# Processing record  514 and 43 skipped|George
# Processing record  515 and 43 skipped|Ust-Maya
# Processing record  516 and 43 skipped|Kedrovyy
# Processing record  517 and 43 skipped|Karpathos
# Processing record  518 and 43 skipped|Palana
# Processing record  519 and 43 skipped|Guozhen
# Processing record  520 and 43 skipped|Deputatsky
# Processing record  521 and 43 skipped|Berlevåg
# Processing record  522 and 43 skipped|Ust'-Barguzin
# Processing record  523 and 43 skipped|Wahiawā
# Processing record  524 and 43 skipped|Jiuquan
# Processing record  525 and 43 skipped|Rūdbār
# Processing record  526 and 43 skipped|Puerto Baquerizo Moreno
# Processing record  527 and 43 skipped|Am Timan
# Processing record  528 and 43 skipped|Logan Lake
# Processing record  529 and 43 skipped|Whitecourt
# Processing record  530 and 43 skipped|Bulungu
# Processing record  531 and 43 skipped|Qandala
# Processing record  532 and 43 skipped|Port-Cartier
# Processing record  533 and 43 skipped|Dubbo
# Processing record  534 and 43 skipped|Hervey Bay
# Processing record  535 and 43 skipped|Srostki
# Processing record  536 and 43 skipped|Aden
# Processing record  537 and 43 skipped|Iquitos
# Processing record  538 and 43 skipped|Bonavista
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert raw data to data frame and export to csv
weather_dat = pd.DataFrame(weather_dic)
weather_dat.to_csv(r'../output_data/cities.csv',index=False, header=True)

# %%
#Call csv in order to avoid excess api usage and time for data collection
csv = '../output_data/cities.csv'
weather_data = pd.read_csv(csv)
weather_data.head()
# Out:
#    City ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0           Bluff           0      NZ  1592509554        83 -46.60
# 1        1       Karpogory          81      RU  1592509554        63  64.00
# 2        2          Albany          39      US  1592509503        58  42.60
# 3        3  Port Elizabeth           0      ZA  1592509554        82 -33.92
# 4        4         Ushuaia          24      AR  1592509554        64 -54.80
#
#       Lng  Max Temp  Wind Speed
# 0  168.33      3.89        1.34
# 1   44.45     12.80        1.98
# 2  -73.97     31.11        0.45
# 3   25.57     14.00        3.10
# 4  -68.30      2.00        3.33

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs. Temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")

# Create a timestamp for today
today_date = pd.Timestamp("today").strftime("%m/%d/%Y")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({today_date})")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.ylim(-5, 50)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature.png")

# %% [markdown]
# ##### 1. Here we can see the highest temperature around equator line, which is 0 Latitude. It is known that temperature is getting higher by moving towards equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({today_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 200)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", alpha=1, edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({today_date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 110)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({today_date})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.ylim(-2, 40)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed.png")

# %% [markdown]
# ##### 2. This dataset shows the same wind speed data around latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
reg_line = ""
def regress(x, y):   
    slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
    regress_values = x*slope + intercept
    global reg_line
    reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
    plt.plot(x, regress_values, "r-", label = "Regression")

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_data
nothern_hem = weather_data.loc[weather_data["Lat"] >= 0, :]
southern_hem = weather_data.loc[weather_data["Lat"] < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build a scatter plot for Northern Hemisphere -Temperature (C) vs. Latitude
plt.scatter(nothern_hem["Lat"], nothern_hem["Max Temp"], marker="o", edgecolors="black")
plt.title("Northern Hemisphere -Temperature (C) vs. Latitude")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
# Add linear regression
regress(nothern_hem['Lat'],nothern_hem['Max Temp'])
plt.annotate(reg_line, (10, 10), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NortHem_Temp_Lat.png")
plt.show()

# %% [markdown]
# ##### 3. We can observe temperature decrease as we're getting far from equator and regression line proves that

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build a scatter plot for Southern Hemisphere -Temperature (C) vs. Latitude
plt.scatter(southern_hem["Lat"], southern_hem["Max Temp"], marker="o", edgecolors="black")
plt.ylabel("Max Temperature (Celsius)")
plt.title("Southern Hemisphere -Temperature (C) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(southern_hem['Lat'],southern_hem['Max Temp'])
plt.annotate(reg_line,(-20, 0), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_Temp_Lat.png")
plt.show()

# %% [markdown]
# ##### 4. We can observe temperature increase as we get closer to equator and regression line proves that

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Northern Hemisphere - Humidity (%) vs. Latitude
plt.scatter(nothern_hem["Lat"], nothern_hem["Humidity"], marker="o", edgecolors="black")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere -Humidity (%) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(nothern_hem['Lat'],nothern_hem['Humidity'])
plt.annotate(reg_line,(50, 10), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NorthHem_Hum_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Southern Hemisphere - Humidity (%) vs. Latitude
plt.scatter(southern_hem["Lat"], southern_hem["Humidity"], marker="o", edgecolors="black")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere -Humidity (%) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(southern_hem['Lat'],southern_hem['Humidity'])
plt.annotate(reg_line,(-50, 20), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_Hum_Lat.png")
plt.show()

# %% [markdown]
# ##### 5. Current dataset shows slight increase in humidity by getting closer to equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Northern Hemisphere - Cloudiness (%) vs. Latitude
plt.scatter(nothern_hem["Lat"], nothern_hem["Cloudiness"], marker="o", edgecolors="black")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(nothern_hem["Lat"], nothern_hem["Cloudiness"])
plt.annotate(reg_line,(-2, 12), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NorthHem_Cloud_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Southern Hemisphere - Cloudiness (%) vs. Latitude
plt.scatter(southern_hem["Lat"], southern_hem["Cloudiness"], marker="o", edgecolors="black")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(southern_hem["Lat"], southern_hem["Cloudiness"])
plt.annotate(reg_line,(-55, 30), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_Cloud_Lat.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Northern Hemisphere - Wind Speed (m/s) vs. Latitude
plt.scatter(nothern_hem["Lat"], nothern_hem["Wind Speed"], marker="o", edgecolors="black")
plt.ylabel("Wind Speed (m/s)")
plt.title("Northern Hemisphere - Wind Speed (m/s) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(nothern_hem["Lat"], nothern_hem["Wind Speed"])
plt.annotate(reg_line,(40, 12), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NorthHem_wind_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
# Build a scatter plot for Southern Hemisphere - Wind Speed (m/s) vs. Latitude
plt.scatter(southern_hem["Lat"], southern_hem["Wind Speed"], marker="o", edgecolors="black")
plt.ylabel("Wind Speed (m/s)")
plt.title("Southern Hemisphere - Wind Speed (m/s) vs. Latitude")
plt.xlabel("Latitude")
# Add linear regression
regress(southern_hem["Lat"], southern_hem["Wind Speed"])
plt.annotate(reg_line,(-55, 7), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_wind_Lat.png")
plt.show()

# %% [markdown]
# ##### 6. There are no crucial relationship between humidity, cloudness and wind speed vs. Latitude
