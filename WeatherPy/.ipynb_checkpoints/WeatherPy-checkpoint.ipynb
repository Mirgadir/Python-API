# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

number = -1
skip = 0
city_name=[]
temp =[]
cloud=[]
country=[]
date=[]
hum=[]
latitude=[]
long=[]
wind=[]
num =[]
print("Beginning of data collection")
print("--------------------------------")
for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        temp.append(response['main']['temp_max'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        hum.append(response['main']['humidity'])
        latitude.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        number+=1
        num.append(number)
        print("Processing record  " +str(number+1)+ " and " + str(skip) + " skipped" + "|" + response['name'])
    except KeyError:
        skip+=1
        print(f"City was not found. Skiping... ")
print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
weather_dic = {
    "City ID": num,"City": city_name, "Cloudiness":cloud, "Country":country, "Date": date, 
    "Humidity": hum, "Lat":latitude, "Lng":long, "Max Temp": temp,"Wind Speed": wind  
}
# Out:
# Beginning of data collection
# --------------------------------
# Processing record  1 and 0 skipped|Koson
# Processing record  2 and 0 skipped|Albany
# Processing record  3 and 0 skipped|Avarua
# Processing record  4 and 0 skipped|Taremskoye
# Processing record  5 and 0 skipped|Ostrovnoy
# Processing record  6 and 0 skipped|Imbituba
# Processing record  7 and 0 skipped|Hibbing
# Processing record  8 and 0 skipped|Bethel
# Processing record  9 and 0 skipped|Rikitea
# Processing record  10 and 0 skipped|Sola
# Processing record  11 and 0 skipped|Fort Nelson
# City was not found. Skiping...
# Processing record  12 and 1 skipped|Ushuaia
# City was not found. Skiping...
# Processing record  13 and 2 skipped|Lumphat
# Processing record  14 and 2 skipped|Paita
# Processing record  15 and 2 skipped|Chara
# Processing record  16 and 2 skipped|Qaanaaq
# Processing record  17 and 2 skipped|Faanui
# Processing record  18 and 2 skipped|Kiunga
# Processing record  19 and 2 skipped|Fortuna
# Processing record  20 and 2 skipped|Bluff
# Processing record  21 and 2 skipped|Lüderitz
# Processing record  22 and 2 skipped|Dahra
# Processing record  23 and 2 skipped|Port Alfred
# Processing record  24 and 2 skipped|Port Elizabeth
# Processing record  25 and 2 skipped|Kapaa
# Processing record  26 and 2 skipped|Cape Town
# Processing record  27 and 2 skipped|Mataura
# Processing record  28 and 2 skipped|São José da Coroa Grande
# Processing record  29 and 2 skipped|Busselton
# Processing record  30 and 2 skipped|Khatanga
# Processing record  31 and 2 skipped|Santiago del Estero
# Processing record  32 and 2 skipped|Butaritari
# Processing record  33 and 2 skipped|Jumla
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  34 and 4 skipped|Evensk
# Processing record  35 and 4 skipped|Nyurba
# Processing record  36 and 4 skipped|Bengkulu
# Processing record  37 and 4 skipped|Nantucket
# Processing record  38 and 4 skipped|Hobart
# Processing record  39 and 4 skipped|Talen
# Processing record  40 and 4 skipped|Gizo Government Station
# Processing record  41 and 4 skipped|Leer
# Processing record  42 and 4 skipped|Ribeira Grande
# Processing record  43 and 4 skipped|Longyearbyen
# Processing record  44 and 4 skipped|Ilulissat
# Processing record  45 and 4 skipped|Atuona
# Processing record  46 and 4 skipped|Galesong
# Processing record  47 and 4 skipped|Kumul
# City was not found. Skiping...
# Processing record  48 and 5 skipped|Konya Province
# Processing record  49 and 5 skipped|Muros
# Processing record  50 and 5 skipped|Nome
# Processing record  51 and 5 skipped|San Patricio
# Processing record  52 and 5 skipped|Ubari
# Processing record  53 and 5 skipped|Jamestown
# Processing record  54 and 5 skipped|Tombouctou
# Processing record  55 and 5 skipped|Hambantota
# Processing record  56 and 5 skipped|Isla Mujeres
# Processing record  57 and 5 skipped|Grass Valley
# Processing record  58 and 5 skipped|Simao
# Processing record  59 and 5 skipped|Touros
# Processing record  60 and 5 skipped|Puerto Ayacucho
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  61 and 7 skipped|Gravdal
# Processing record  62 and 7 skipped|Kulhudhuffushi
# Processing record  63 and 7 skipped|Labuhan
# Processing record  64 and 7 skipped|Airai
# City was not found. Skiping...
# Processing record  65 and 8 skipped|Pisco
# Processing record  66 and 8 skipped|Vila Velha
# Processing record  67 and 8 skipped|Chokurdakh
# Processing record  68 and 8 skipped|Staryy Nadym
# Processing record  69 and 8 skipped|Vaini
# Processing record  70 and 8 skipped|Estelle
# Processing record  71 and 8 skipped|Clive
# Processing record  72 and 8 skipped|Esperance
# Processing record  73 and 8 skipped|Upata
# Processing record  74 and 8 skipped|Gbarnga
# Processing record  75 and 8 skipped|Pauini
# Processing record  76 and 8 skipped|Āsosa
# Processing record  77 and 8 skipped|Westport
# Processing record  78 and 8 skipped|Mar del Plata
# Processing record  79 and 8 skipped|São João da Barra
# Processing record  80 and 8 skipped|Baykit
# Processing record  81 and 8 skipped|Erzin
# Processing record  82 and 8 skipped|Ahipara
# Processing record  83 and 8 skipped|Bathsheba
# Processing record  84 and 8 skipped|Zyryanka
# Processing record  85 and 8 skipped|Saint Paul Harbor
# Processing record  86 and 8 skipped|Taltal
# Processing record  87 and 8 skipped|Dombarovskiy
# City was not found. Skiping...
# Processing record  88 and 9 skipped|Bredasdorp
# Processing record  89 and 9 skipped|Hilo
# Processing record  90 and 9 skipped|Bonavista
# Processing record  91 and 9 skipped|Yellowknife
# Processing record  92 and 9 skipped|Punta Arenas
# Processing record  93 and 9 skipped|Rawson
# Processing record  94 and 9 skipped|Ruteng
# Processing record  95 and 9 skipped|East London
# Processing record  96 and 9 skipped|Fairbanks
# Processing record  97 and 9 skipped|Hope
# Processing record  98 and 9 skipped|Saint-Pierre
# Processing record  99 and 9 skipped|Margate
# Processing record  100 and 9 skipped|Balclutha
# Processing record  101 and 9 skipped|Dingle
# Processing record  102 and 9 skipped|Itagi
# Processing record  103 and 9 skipped|Chui
# Processing record  104 and 9 skipped|Asău
# Processing record  105 and 9 skipped|Saint-Joseph
# Processing record  106 and 9 skipped|Dikson
# Processing record  107 and 9 skipped|Lebu
# Processing record  108 and 9 skipped|Hong Kong
# Processing record  109 and 9 skipped|Aransas Pass
# City was not found. Skiping...
# Processing record  110 and 10 skipped|Barrow
# Processing record  111 and 10 skipped|Spirit River
# Processing record  112 and 10 skipped|Salinópolis
# Processing record  113 and 10 skipped|Thompson
# Processing record  114 and 10 skipped|Xudat
# Processing record  115 and 10 skipped|Talara
# Processing record  116 and 10 skipped|Mae Sai
# Processing record  117 and 10 skipped|Tiksi
# Processing record  118 and 10 skipped|Saint-Philippe
# City was not found. Skiping...
# Processing record  119 and 11 skipped|Vestmannaeyjar
# City was not found. Skiping...
# Processing record  120 and 12 skipped|Hermanus
# Processing record  121 and 12 skipped|Qaqortoq
# Processing record  122 and 12 skipped|Oranjestad
# Processing record  123 and 12 skipped|Arrondissement d'Arcachon
# Processing record  124 and 12 skipped|Sharjah city
# Processing record  125 and 12 skipped|Kahului
# Processing record  126 and 12 skipped|Jobabo
# Processing record  127 and 12 skipped|Uray
# Processing record  128 and 12 skipped|Blackwater
# City was not found. Skiping...
# Processing record  129 and 13 skipped|Saint George
# Processing record  130 and 13 skipped|Severo-Kuril'sk
# Processing record  131 and 13 skipped|Oktyabr'skiy
# Processing record  132 and 13 skipped|Broome
# Processing record  133 and 13 skipped|Teningen
# Processing record  134 and 13 skipped|Pala
# Processing record  135 and 13 skipped|Flinders
# Processing record  136 and 13 skipped|Kachug
# Processing record  137 and 13 skipped|Cururupu
# Processing record  138 and 13 skipped|Cairns
# Processing record  139 and 13 skipped|George Town
# Processing record  140 and 13 skipped|Pasni
# Processing record  141 and 13 skipped|Kruisfontein
# City was not found. Skiping...
# Processing record  142 and 14 skipped|Cabo San Lucas
# Processing record  143 and 14 skipped|Pevek
# Processing record  144 and 14 skipped|Cidreira
# Processing record  145 and 14 skipped|Dudinka
# Processing record  146 and 14 skipped|Alyangula
# Processing record  147 and 14 skipped|Sohbatpur
# Processing record  148 and 14 skipped|Rānia
# Processing record  149 and 14 skipped|Geraldton
# Processing record  150 and 14 skipped|Kavieng
# Processing record  151 and 14 skipped|Pilot Butte
# Processing record  152 and 14 skipped|Vardø
# Processing record  153 and 14 skipped|Lagoa
# Processing record  154 and 14 skipped|Funadhoo
# Processing record  155 and 14 skipped|Malaṅgawā
# Processing record  156 and 14 skipped|Nevel'sk
# Processing record  157 and 14 skipped|Batagay-Alyta
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  158 and 16 skipped|Xingcheng
# Processing record  159 and 16 skipped|Beloha
# Processing record  160 and 16 skipped|Ponta do Sol
# Processing record  161 and 16 skipped|Adeje
# Processing record  162 and 16 skipped|Denpasar
# Processing record  163 and 16 skipped|Bilma
# Processing record  164 and 16 skipped|Rengo
# Processing record  165 and 16 skipped|New Norfolk
# Processing record  166 and 16 skipped|Half Moon Bay
# Processing record  167 and 16 skipped|Behshahr
# Processing record  168 and 16 skipped|Huarmey
# City was not found. Skiping...
# Processing record  169 and 17 skipped|Moses Lake
# Processing record  170 and 17 skipped|Kalat
# Processing record  171 and 17 skipped|Perth
# Processing record  172 and 17 skipped|Green River
# Processing record  173 and 17 skipped|Saskylakh
# Processing record  174 and 17 skipped|Prince Rupert
# Processing record  175 and 17 skipped|Sapucaia
# Processing record  176 and 17 skipped|Dhidhdhoo
# Processing record  177 and 17 skipped|Cockburn Town
# Processing record  178 and 17 skipped|Constitución
# City was not found. Skiping...
# Processing record  179 and 18 skipped|Tambacounda
# Processing record  180 and 18 skipped|Lorengau
# Processing record  181 and 18 skipped|Lata
# Processing record  182 and 18 skipped|Ayagoz
# City was not found. Skiping...
# Processing record  183 and 19 skipped|Tondano
# Processing record  184 and 19 skipped|Mayo
# Processing record  185 and 19 skipped|Sibolga
# Processing record  186 and 19 skipped|Amapá
# Processing record  187 and 19 skipped|Dundee
# Processing record  188 and 19 skipped|Huilong
# Processing record  189 and 19 skipped|Guerrero Negro
# Processing record  190 and 19 skipped|Laguna
# Processing record  191 and 19 skipped|Mendota
# Processing record  192 and 19 skipped|Bilibino
# Processing record  193 and 19 skipped|Neepawa
# Processing record  194 and 19 skipped|Pacasmayo
# Processing record  195 and 19 skipped|Novovarshavka
# Processing record  196 and 19 skipped|Virtsu
# Processing record  197 and 19 skipped|Souillac
# Processing record  198 and 19 skipped|Polonnaruwa
# Processing record  199 and 19 skipped|Maceió
# Processing record  200 and 19 skipped|Chernyshkovskiy
# Processing record  201 and 19 skipped|Pochutla
# Processing record  202 and 19 skipped|Lhokseumawe
# City was not found. Skiping...
# Processing record  203 and 20 skipped|Goderich
# Processing record  204 and 20 skipped|Tuktoyaktuk
# Processing record  205 and 20 skipped|Skoghall
# Processing record  206 and 20 skipped|Talcahuano
# City was not found. Skiping...
# Processing record  207 and 21 skipped|Sabang
# Processing record  208 and 21 skipped|Esna
# Processing record  209 and 21 skipped|Pocatello
# Processing record  210 and 21 skipped|Viedma
# Processing record  211 and 21 skipped|Leningradskiy
# Processing record  212 and 21 skipped|Majene
# Processing record  213 and 21 skipped|Ariquemes
# Processing record  214 and 21 skipped|Ust-Tsilma
# Processing record  215 and 21 skipped|Poum
# Processing record  216 and 21 skipped|Bambous Virieux
# Processing record  217 and 21 skipped|Samarai
# Processing record  218 and 21 skipped|Kostanay
# Processing record  219 and 21 skipped|Trail
# Processing record  220 and 21 skipped|Ust-Kuyga
# Processing record  221 and 21 skipped|Portland
# Processing record  222 and 21 skipped|Namatanai
# Processing record  223 and 21 skipped|Tasiilaq
# Processing record  224 and 21 skipped|Jalalabad
# Processing record  225 and 21 skipped|Villarrica
# Processing record  226 and 21 skipped|Broken Hill
# Processing record  227 and 21 skipped|Kiama
# Processing record  228 and 21 skipped|Saldanha
# Processing record  229 and 21 skipped|Coyhaique
# Processing record  230 and 21 skipped|Kaabong
# Processing record  231 and 21 skipped|Hofn
# Processing record  232 and 21 skipped|Calama
# Processing record  233 and 21 skipped|Porto-Novo
# Processing record  234 and 21 skipped|Cayenne
# Processing record  235 and 21 skipped|Ambovombe
# Processing record  236 and 21 skipped|San Cristobal
# Processing record  237 and 21 skipped|Loandjili
# Processing record  238 and 21 skipped|Hervey Bay
# Processing record  239 and 21 skipped|Port-Gentil
# Processing record  240 and 21 skipped|Narsaq
# Processing record  241 and 21 skipped|Eirunepé
# Processing record  242 and 21 skipped|Emerald
# City was not found. Skiping...
# Processing record  243 and 22 skipped|Phuket
# Processing record  244 and 22 skipped|Berlevåg
# City was not found. Skiping...
# Processing record  245 and 23 skipped|Blythe
# Processing record  246 and 23 skipped|Jati
# Processing record  247 and 23 skipped|Flin Flon
# Processing record  248 and 23 skipped|Coquimbo
# Processing record  249 and 23 skipped|Juneau
# City was not found. Skiping...
# Processing record  250 and 24 skipped|Zonguldak
# City was not found. Skiping...
# Processing record  251 and 25 skipped|Algiers
# Processing record  252 and 25 skipped|Arraial do Cabo
# Processing record  253 and 25 skipped|Sungai Penuh
# Processing record  254 and 25 skipped|Puerto Escondido
# Processing record  255 and 25 skipped|Filingué
# Processing record  256 and 25 skipped|Puerto Ayora
# Processing record  257 and 25 skipped|Yar-Sale
# Processing record  258 and 25 skipped|Mount Gambier
# Processing record  259 and 25 skipped|Kankaanpää
# Processing record  260 and 25 skipped|Vilyuysk
# Processing record  261 and 25 skipped|Ayan
# Processing record  262 and 25 skipped|Słupsk
# Processing record  263 and 25 skipped|Upernavik
# Processing record  264 and 25 skipped|Shiringushi
# Processing record  265 and 25 skipped|Sembakung
# Processing record  266 and 25 skipped|Kabanjahe
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  267 and 27 skipped|Katsuura
# Processing record  268 and 27 skipped|Klaksvík
# City was not found. Skiping...
# Processing record  269 and 28 skipped|Sæby
# Processing record  270 and 28 skipped|Ixtapa
# Processing record  271 and 28 skipped|Rafsanjān
# Processing record  272 and 28 skipped|Frankfort
# City was not found. Skiping...
# Processing record  273 and 29 skipped|Narasannapeta
# Processing record  274 and 29 skipped|Kaitangata
# Processing record  275 and 29 skipped|Seydi
# Processing record  276 and 29 skipped|Aklavik
# Processing record  277 and 29 skipped|Camacha
# Processing record  278 and 29 skipped|Umeå
# Processing record  279 and 29 skipped|Kloulklubed
# Processing record  280 and 29 skipped|Daokou
# Processing record  281 and 29 skipped|Cherskiy
# Processing record  282 and 29 skipped|Carnarvon
# Processing record  283 and 29 skipped|Khani
# Processing record  284 and 29 skipped|Sri Aman
# Processing record  285 and 29 skipped|Vaitape
# Processing record  286 and 29 skipped|Guozhen
# Processing record  287 and 29 skipped|Xixiang
# Processing record  288 and 29 skipped|Paamiut
# Processing record  289 and 29 skipped|Goma
# Processing record  290 and 29 skipped|Bariloche
# Processing record  291 and 29 skipped|Pangnirtung
# Processing record  292 and 29 skipped|Kovūr
# Processing record  293 and 29 skipped|Natchez
# Processing record  294 and 29 skipped|Kontagora
# Processing record  295 and 29 skipped|Torbay
# Processing record  296 and 29 skipped|Rohatyn
# Processing record  297 and 29 skipped|Horsham
# Processing record  298 and 29 skipped|Norman Wells
# Processing record  299 and 29 skipped|Muncar
# Processing record  300 and 29 skipped|Tura
# Processing record  301 and 29 skipped|Sena Madureira
# Processing record  302 and 29 skipped|Castro
# Processing record  303 and 29 skipped|At-Bashi
# Processing record  304 and 29 skipped|Niono
# Processing record  305 and 29 skipped|Richards Bay
# Processing record  306 and 29 skipped|Kendari
# Processing record  307 and 29 skipped|Suriāpet
# Processing record  308 and 29 skipped|Jalu
# Processing record  309 and 29 skipped|Kingsport
# Processing record  310 and 29 skipped|Nikolskoye
# Processing record  311 and 29 skipped|Mana
# Processing record  312 and 29 skipped|Sambava
# Processing record  313 and 29 skipped|Chumikan
# Processing record  314 and 29 skipped|Piteå
# Processing record  315 and 29 skipped|Champerico
# City was not found. Skiping...
# Processing record  316 and 30 skipped|Karasjok
# Processing record  317 and 30 skipped|Kaohsiung City
# Processing record  318 and 30 skipped|Sahuaripa
# Processing record  319 and 30 skipped|Bandarbeyla
# Processing record  320 and 30 skipped|Mitsamiouli
# Processing record  321 and 30 skipped|La Ronge
# Processing record  322 and 30 skipped|Río Gallegos
# Processing record  323 and 30 skipped|Worthington
# Processing record  324 and 30 skipped|Mount Isa
# Processing record  325 and 30 skipped|Oodweyne
# Processing record  326 and 30 skipped|Parrita
# Processing record  327 and 30 skipped|Moultrie
# Processing record  328 and 30 skipped|Riyadh
# Processing record  329 and 30 skipped|Wilmington
# Processing record  330 and 30 skipped|Hunchun
# City was not found. Skiping...
# Processing record  331 and 31 skipped|Yanam
# City was not found. Skiping...
# Processing record  332 and 32 skipped|Hearst
# Processing record  333 and 32 skipped|Ust-Nera
# Processing record  334 and 32 skipped|Chapais
# Processing record  335 and 32 skipped|Banjar
# Processing record  336 and 32 skipped|Roebourne
# Processing record  337 and 32 skipped|Uyuni
# Processing record  338 and 32 skipped|Mitchell
# Processing record  339 and 32 skipped|Tabou
# Processing record  340 and 32 skipped|Guangyuan
# Processing record  341 and 32 skipped|Auki
# Processing record  342 and 32 skipped|Muzhi
# City was not found. Skiping...
# Processing record  343 and 33 skipped|Chapleau
# Processing record  344 and 33 skipped|Martapura
# Processing record  345 and 33 skipped|Qingquan
# Processing record  346 and 33 skipped|Olginskaya
# Processing record  347 and 33 skipped|Gmina Opole Lubelskie
# Processing record  348 and 33 skipped|Maragogi
# Processing record  349 and 33 skipped|Xining
# Processing record  350 and 33 skipped|Okha
# Processing record  351 and 33 skipped|Muğla Province
# Processing record  352 and 33 skipped|Aswān
# Processing record  353 and 33 skipped|Pimentel
# Processing record  354 and 33 skipped|Amasya
# Processing record  355 and 33 skipped|Alofi
# Processing record  356 and 33 skipped|Grindavik
# Processing record  357 and 33 skipped|Sumbe
# Processing record  358 and 33 skipped|Ulaanbaatar
# Processing record  359 and 33 skipped|Kondinskoye
# Processing record  360 and 33 skipped|Caravelas
# City was not found. Skiping...
# Processing record  361 and 34 skipped|Alekseyevka
# Processing record  362 and 34 skipped|Kyren
# Processing record  363 and 34 skipped|Hithadhoo
# Processing record  364 and 34 skipped|Hasaki
# Processing record  365 and 34 skipped|Shingū
# Processing record  366 and 34 skipped|Rabo de Peixe
# Processing record  367 and 34 skipped|Mercedes
# Processing record  368 and 34 skipped|Manaure
# Processing record  369 and 34 skipped|Praia da Vitória
# Processing record  370 and 34 skipped|Zaraza
# Processing record  371 and 34 skipped|Balkanabat
# Processing record  372 and 34 skipped|Bemidji
# Processing record  373 and 34 skipped|Matara
# Processing record  374 and 34 skipped|Port Moresby
# Processing record  375 and 34 skipped|Port Macquarie
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  376 and 36 skipped|San Policarpo
# Processing record  377 and 36 skipped|Zhuhai
# Processing record  378 and 36 skipped|Ucluelet
# Processing record  379 and 36 skipped|Linqing
# Processing record  380 and 36 skipped|Ballina
# Processing record  381 and 36 skipped|Kwang Binh
# Processing record  382 and 36 skipped|Olinda
# Processing record  383 and 36 skipped|Meulaboh
# Processing record  384 and 36 skipped|Chekhov
# Processing record  385 and 36 skipped|Talaya
# Processing record  386 and 36 skipped|Chulym
# Processing record  387 and 36 skipped|Lavrentiya
# Processing record  388 and 36 skipped|Aksu
# Processing record  389 and 36 skipped|Rome
# Processing record  390 and 36 skipped|Natal
# Processing record  391 and 36 skipped|Tiznit Province
# Processing record  392 and 36 skipped|São Filipe
# Processing record  393 and 36 skipped|Nagato
# City was not found. Skiping...
# Processing record  394 and 37 skipped|Athabasca
# Processing record  395 and 37 skipped|Salalah
# Processing record  396 and 37 skipped|Ewo
# City was not found. Skiping...
# Processing record  397 and 38 skipped|Ulladulla
# Processing record  398 and 38 skipped|San Clemente
# Processing record  399 and 38 skipped|Manuk Mangkaw
# Processing record  400 and 38 skipped|Korba
# Processing record  401 and 38 skipped|Aldergrove
# Processing record  402 and 38 skipped|Okhotsk
# Processing record  403 and 38 skipped|Pacific Grove
# Processing record  404 and 38 skipped|Zhigansk
# Processing record  405 and 38 skipped|Padang
# Processing record  406 and 38 skipped|Sabzawār
# Processing record  407 and 38 skipped|Arrondissement de Roanne
# Processing record  408 and 38 skipped|Beba
# Processing record  409 and 38 skipped|Nchelenge
# Processing record  410 and 38 skipped|Novoomskiy
# City was not found. Skiping...
# Processing record  411 and 39 skipped|Kirn
# Processing record  412 and 39 skipped|Beringovskiy
# Processing record  413 and 39 skipped|Bairiki Village
# Processing record  414 and 39 skipped|Clarence Town
# Processing record  415 and 39 skipped|Babylon
# Processing record  416 and 39 skipped|Luanda
# Processing record  417 and 39 skipped|Palamós
# Processing record  418 and 39 skipped|Chegdomyn
# Processing record  419 and 39 skipped|Henties Bay
# Processing record  420 and 39 skipped|Khuzhir
# Processing record  421 and 39 skipped|Yanji
# Processing record  422 and 39 skipped|Byron Bay
# Processing record  423 and 39 skipped|La Libertad
# Processing record  424 and 39 skipped|Kargasok
# Processing record  425 and 39 skipped|Tcholliré
# Processing record  426 and 39 skipped|Bima
# Processing record  427 and 39 skipped|Oddur
# Processing record  428 and 39 skipped|Abu Dhabi
# Processing record  429 and 39 skipped|Tuy Hoa
# Processing record  430 and 39 skipped|Mackay
# Processing record  431 and 39 skipped|Itambacuri
# Processing record  432 and 39 skipped|Sur
# Processing record  433 and 39 skipped|La Santisima Trinidad
# Processing record  434 and 39 skipped|Mnogovershinnyy
# Processing record  435 and 39 skipped|Husavik
# Processing record  436 and 39 skipped|Talnakh
# Processing record  437 and 39 skipped|Aleksandrov Gay
# Processing record  438 and 39 skipped|Ancud
# Processing record  439 and 39 skipped|Grand Gaube
# Processing record  440 and 39 skipped|Kavaratti
# Processing record  441 and 39 skipped|Hamilton
# City was not found. Skiping...
# Processing record  442 and 40 skipped|Baker City
# Processing record  443 and 40 skipped|Arroyo de la Encomienda
# Processing record  444 and 40 skipped|Porto Murtinho
# Processing record  445 and 40 skipped|Zhangye
# Processing record  446 and 40 skipped|Kimbe
# Processing record  447 and 40 skipped|Manaus
# Processing record  448 and 40 skipped|Yerbogachën
# Processing record  449 and 40 skipped|Cabinda
# Processing record  450 and 40 skipped|Vestmanna
# Processing record  451 and 40 skipped|Arlit
# Processing record  452 and 40 skipped|Lompoc
# Processing record  453 and 40 skipped|Sioux Lookout
# Processing record  454 and 40 skipped|Rio Claro
# Processing record  455 and 40 skipped|Katikati
# Processing record  456 and 40 skipped|Walvis Bay
# Processing record  457 and 40 skipped|Store Heddinge
# Processing record  458 and 40 skipped|Quesnel
# Processing record  459 and 40 skipped|Kuril'sk
# Processing record  460 and 40 skipped|Nanortalik
# Processing record  461 and 40 skipped|Rafai
# Processing record  462 and 40 skipped|Sochaczew
# City was not found. Skiping...
# Processing record  463 and 41 skipped|Grand-Santi
# Processing record  464 and 41 skipped|Atar
# Processing record  465 and 41 skipped|Sulęcin
# Processing record  466 and 41 skipped|Antofagasta
# Processing record  467 and 41 skipped|Sitka
# Processing record  468 and 41 skipped|Araouane
# Processing record  469 and 41 skipped|Tessalit
# Processing record  470 and 41 skipped|Palapye
# Processing record  471 and 41 skipped|Marsá Maţrūḩ
# Processing record  472 and 41 skipped|Dicabisagan
# Processing record  473 and 41 skipped|The Valley
# Processing record  474 and 41 skipped|Hanting
# Processing record  475 and 41 skipped|Vao
# Processing record  476 and 41 skipped|Tilichiki
# Processing record  477 and 41 skipped|Pomoriany
# City was not found. Skiping...
# Processing record  478 and 42 skipped|Mahébourg
# Processing record  479 and 42 skipped|João Pinheiro
# Processing record  480 and 42 skipped|Alnashi
# Processing record  481 and 42 skipped|Launceston
# Processing record  482 and 42 skipped|Verkhoyansk
# Processing record  483 and 42 skipped|Baikunthpur
# Processing record  484 and 42 skipped|Wadena
# Processing record  485 and 42 skipped|Mujiayingzi
# Processing record  486 and 42 skipped|Mogadishu
# Processing record  487 and 42 skipped|Emilio Carranza
# Processing record  488 and 42 skipped|Havre-St-Pierre
# Processing record  489 and 42 skipped|Thunder Bay
# Processing record  490 and 42 skipped|Makakilo City
# Processing record  491 and 42 skipped|Bāgli
# Processing record  492 and 42 skipped|Argentan
# City was not found. Skiping...
# Processing record  493 and 43 skipped|Nālūt
# Processing record  494 and 43 skipped|Lilongwe
# Processing record  495 and 43 skipped|Ossora
# Processing record  496 and 43 skipped|Koumac
# Processing record  497 and 43 skipped|Buraidah
# Processing record  498 and 43 skipped|Dakar
# Processing record  499 and 43 skipped|Kerema
# Processing record  500 and 43 skipped|Nouadhibou
# Processing record  501 and 43 skipped|Skellefteå
# Processing record  502 and 43 skipped|Encruzilhada do Sul
# Processing record  503 and 43 skipped|Ust-Maya
# Processing record  504 and 43 skipped|Isangel
# Processing record  505 and 43 skipped|Kungurtug
# Processing record  506 and 43 skipped|Cervo
# Processing record  507 and 43 skipped|Soddy-Daisy
# City was not found. Skiping...
# Processing record  508 and 44 skipped|Dāmghān
# Processing record  509 and 44 skipped|Vila Franca do Campo
# Processing record  510 and 44 skipped|Prieska
# Processing record  511 and 44 skipped|Vanimo
# Processing record  512 and 44 skipped|Belmonte
# Processing record  513 and 44 skipped|Klooga
# Processing record  514 and 44 skipped|Chihuahua
# Processing record  515 and 44 skipped|Senneterre
# City was not found. Skiping...
# City was not found. Skiping...
# Processing record  516 and 46 skipped|Solnechnyy
# City was not found. Skiping...
# Processing record  517 and 47 skipped|Visnes
# Processing record  518 and 47 skipped|Nuevo Progreso
# Processing record  519 and 47 skipped|Piterka
# Processing record  520 and 47 skipped|Tartagal
# Processing record  521 and 47 skipped|Oudtshoorn
# Processing record  522 and 47 skipped|Slave Lake
# Processing record  523 and 47 skipped|Sangmélima
# Processing record  524 and 47 skipped|Ordzhonīkīdze
# Processing record  525 and 47 skipped|‘Āhuimanu
# Processing record  526 and 47 skipped|Meylan
# Processing record  527 and 47 skipped|Naze
# Processing record  528 and 47 skipped|Tabuk
# Processing record  529 and 47 skipped|Gewanē
# City was not found. Skiping...
# Processing record  530 and 48 skipped|Celestún
# City was not found. Skiping...
# Processing record  531 and 49 skipped|Progreso
# Processing record  532 and 49 skipped|Yulara
# Processing record  533 and 49 skipped|Mayumba
# Processing record  534 and 49 skipped|Kushima
# Processing record  535 and 49 skipped|Mungwi
# Processing record  536 and 49 skipped|Trois-Rivières
# Processing record  537 and 49 skipped|Dossor
# Processing record  538 and 49 skipped|Puerto Quijarro
# Processing record  539 and 49 skipped|Onokhoy
# Processing record  540 and 49 skipped|Christchurch
# Processing record  541 and 49 skipped|Coruripe
# Processing record  542 and 49 skipped|Alugan
# Processing record  543 and 49 skipped|Lahaina
# Processing record  544 and 49 skipped|Port Blair
# Processing record  545 and 49 skipped|Nishihara
# Processing record  546 and 49 skipped|Fukuechō
# Processing record  547 and 49 skipped|San Carlos
# Processing record  548 and 49 skipped|New Glasgow
# Processing record  549 and 49 skipped|Atambua
# Processing record  550 and 49 skipped|Vikulovo
# Processing record  551 and 49 skipped|Karratha
# Processing record  552 and 49 skipped|Moerai
# Processing record  553 and 49 skipped|Takoradze
# Processing record  554 and 49 skipped|Te Anau
# Processing record  555 and 49 skipped|Taoudenni
# Processing record  556 and 49 skipped|Aasiaat
# Processing record  557 and 49 skipped|Pahlgām
# Processing record  558 and 49 skipped|Conde
# City was not found. Skiping...
# Processing record  559 and 50 skipped|Kuusamo
# Processing record  560 and 50 skipped|Sept-Îles
# Processing record  561 and 50 skipped|Oistins
# Processing record  562 and 50 skipped|Plettenberg Bay
# Processing record  563 and 50 skipped|Dumai
# Processing record  564 and 50 skipped|La Romana
# Processing record  565 and 50 skipped|Dūngarpur
# Processing record  566 and 50 skipped|Provideniya
# Processing record  567 and 50 skipped|Mindelo
# Processing record  568 and 50 skipped|Boa Vista
# Processing record  569 and 50 skipped|Nioro
# Processing record  570 and 50 skipped|Srednekolymsk
# Processing record  571 and 50 skipped|Hyères
# Processing record  572 and 50 skipped|Honiara
# Processing record  573 and 50 skipped|Zinder
# Processing record  574 and 50 skipped|Los Llanos de Aridane
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert raw data to data frame and export to csv
weather_dat = pd.DataFrame(weather_dic)
weather_dat.to_csv(r'../output_data/cities.csv',index=False, header=True)

# %%
#Call csv in order to avoid excess time for data collection
csv = '../output_data/cities.csv'
weather_data = pd.read_csv(csv)
weather_data.head()
# Out:
#    City ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0       Koson           1      UZ  1592367298        26  39.04
# 1        1      Albany           0      US  1592367298        62  42.60
# 2        2      Avarua           0      CK  1592367298        64 -21.21
# 3        3  Taremskoye         100      RU  1592367298        77  55.93
# 4        4   Ostrovnoy          80      RU  1592367298        70  68.05
#
#       Lng  Max Temp  Wind Speed
# 0   65.58     28.00        3.10
# 1  -73.97     18.89        1.37
# 2 -159.78     23.00        3.10
# 3   43.04     20.00        1.00
# 4   39.51      6.92        6.90

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs. Temperature
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolors="black")

# Create a timestamp for today
today_date = pd.Timestamp("today").strftime("%m/%d/%Y")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Max Temperature ({today_date})")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.ylim(-5, 45)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature.png")

# %% [markdown]
# ##### Here we can see the highest temperature around equator line, which is 0 Latitude.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs. Humidity
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({today_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 200)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Humidity.png")

# %% [markdown]
# ##### In this graph we can see less humid zones around -20 Latitude and 20-40 Latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", alpha=1, edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({today_date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(-10, 110)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Cloudiness.png")

# %% [markdown]
# ##### For current dataset cities around -40 Latitude have less cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs. Wind Speed
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Wind Speed ({today_date})")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.ylim(-2, 40)
plt.grid(True)

# Save the figure
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed.png")

# %% [markdown]
# ##### This dataset shows the same wind speed data around latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
#def regress(x, y):   
    #slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
    #regress_values = x*slope + intercept
    #reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
    #plt.plot(x, regress_values, "r-", label = "Regression"

# %%
# Create Northern and Southern Hemisphere DataFrames
weather_data
nothern_hem = weather_data.loc[weather_data["Lat"] >= 0, :]
southern_hem = weather_data.loc[weather_data["Lat"] < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Build a scatter plot for Northern Hemisphere -Temperature (C) vs. Latitude

x=nothern_hem['Lat']
y=nothern_hem['Max Temp']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")



plt.scatter(nothern_hem["Lat"], nothern_hem["Max Temp"], marker="o", edgecolors="black")
plt.title("Northern Hemisphere -Temperature (C) vs. Latitude")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
# Add linear regression
plt.annotate(reg_line, (10, 10), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NortHem_Temp_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x=southern_hem['Lat']
y=southern_hem['Max Temp']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")



plt.scatter(southern_hem["Lat"], southern_hem["Max Temp"], marker="o", edgecolors="black")
plt.ylabel("Max Temperature (Celsius)")
plt.title("Southern Hemisphere -Temperature (C) vs. Latitude")
plt.xlabel("Latitude")
plt.annotate(reg_line,(-20, 0), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_Temp_Lat.png")
plt.show()

# %% [markdown]
# ##### We can observe temperature increase as we get closer to equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=nothern_hem['Lat']
y=nothern_hem['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")



plt.scatter(nothern_hem["Lat"], nothern_hem["Humidity"], marker="o", edgecolors="black")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere -Humidity (%) vs. Latitude")
plt.xlabel("Latitude")

plt.annotate(reg_line,(50, 10), fontsize=11, color="red")

# Save the figure
plt.savefig("../output_data/NorthHem_Hum_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=southern_hem['Lat']
y=southern_hem['Humidity']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")



plt.scatter(southern_hem["Lat"], southern_hem["Humidity"], marker="o", edgecolors="black")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere -Humidity (%) vs. Latitude")
plt.xlabel("Latitude")
lin(southern_hem["Lat"], southern_hem["Humidity"])
plt.annotate(reg_line,(-50, 20), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/SouthHem_Hum_Lat.png")
plt.show()

# %% [markdown]
# ##### Current dataset shows slight increase in humidity by getting closer to equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=nothern_hem['Lat']
y=nothern_hem['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")



plt.scatter(nothern_hem["Lat"], nothern_hem["Cloudiness"], marker="o", edgecolors="black")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
lin(nothern_hem["Lat"], nothern_hem["Cloudiness"])
plt.annotate(reg_line,(-2, 12), fontsize=11, color="red")


# Save the figure
plt.savefig("../output_data/NorthHem_Cloud_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=southern_hem['Lat']
y=southern_hem['Cloudiness']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")


plt.scatter(southern_hem["Lat"], southern_hem["Cloudiness"], marker="o", edgecolors="black")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel("Latitude")
lin(southern_hem["Lat"], southern_hem["Cloudiness"])
plt.annotate(reg_line,(-55, 30), fontsize=11, color="red")


# Save the figure
plt.savefig("../output_data/SouthHem_Cloud_Lat.png")
plt.show()

# %% [markdown]
# ##### Current dataset doesn't show correct information around equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
x=nothern_hem['Lat']
y=nothern_hem['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")


plt.scatter(nothern_hem["Lat"], nothern_hem["Wind Speed"], marker="o", edgecolors="black")
plt.ylabel("Wind Speed (m/s)")
plt.title("Northern Hemisphere - Wind Speed (m/s) vs. Latitude")
plt.xlabel("Latitude")
lin(nothern_hem["Lat"], nothern_hem["Wind Speed"])
plt.annotate(reg_line,(40, 10), fontsize=11, color="red")
# Save the figure
plt.savefig("../output_data/NorthHem_wind_Lat.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
x=southern_hem['Lat']
y=southern_hem['Wind Speed']

slope, intercept, rvalue, pvalue, stderr = linregress(x,y)
regress_values = x*slope + intercept
reg_line="y= " + str(round(slope,2)) + "x + " +str(round(intercept,2))
plt.plot(x, regress_values, "r-", label = "Regression")


plt.scatter(southern_hem["Lat"], southern_hem["Wind Speed"], marker="o", edgecolors="black")
plt.ylabel("Wind Speed (m/s)")
plt.title("Southern Hemisphere - Wind Speed (m/s) vs. Latitude")
plt.xlabel("Latitude")
lin(southern_hem["Lat"], southern_hem["Wind Speed"])
plt.annotate(reg_line,(-50, 7), fontsize=11, color="red")
plt.savefig("../output_data/SouthHem_wind_Lat.png")
plt.show()

# %% [markdown]
# ##### There are no crucial relationship between humidity, cloudness and wind speed vs. Latitude
